# %% [markdown]
# ## Data Aggrigation

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_train = pd.read_csv('drugsComTrain_raw.csv')
df_test = pd.read_csv('drugsComTest_raw.csv')

# %%
data = pd.concat([df_train,df_test])

# %%
data.sample(5)
# Out:
#         uniqueID                            drugName                condition  \
# 6689      205129  Acetaminophen / aspirin / caffeine                 Migraine
# 19894     184345                         Hydroxyzine                  Anxiety
# 153874    221941                         Fluconazole  Vaginal Yeast Infection
# 88151      67396                          Lacosamide                 Seizures
# 83925      70605                              Flomax     Urinary Tract Stones
#
#                                                    review  rating       date  \
# 6689    "I was diagnosed with a brain tumor and this w...      10   9-Oct-13
# 19894   "It worked for a while then it stopped working...       1  12-Mar-15
# 153874  "I took the 150mg and within 24 hrs I felt way...      10   4-Apr-17
# 88151   "I have been on Vimpat for four years and have...      10  21-Apr-17
# 83925   "Helped me pass my stone within 3 hours of tak...      10  27-Aug-09
#
#         usefulCount
# 6689             18
# 19894            30
# 153874           16
# 88151            26
# 83925            66

# %%
df = data.copy()

# %%
df.sample(10)
# Out:
#         uniqueID        drugName                          condition  \
# 52819      63262   Difluprednate  Postoperative Ocular Inflammation
# 14155      63290          Epiduo                               Acne
# 28608      13103          Xolair                Asthma, Maintenance
# 47919      31753      Miconazole            Vaginal Yeast Infection
# 78384      56146       Estradiol                 Atrophic Vaginitis
# 88297       9329  Lo Loestrin Fe                      Birth Control
# 53131     139483     Armodafinil                        Hypersomnia
# 159679    172505      Clonazepam                            Anxiety
# 34695     142839  Levonorgestrel                      Birth Control
# 17217     183492        Cymbalta                        ibromyalgia
#
#                                                    review  rating       date  \
# 52819   "Durezol was prescribed by my doctor following...      10  28-Sep-13
# 14155   "I used to use Adapalene only which was very s...      10  22-Aug-17
# 28608   "6 months 2 injections every 2 week.  Sorry gu...       1  21-Nov-17
# 47919   "Ok everyone, I have frequent yeast infections...       9   6-Dec-15
# 78384   "I didn&#039;t realize how much this was a gre...      10   2-Aug-09
# 88297   "This is my first ever pill I used. The first ...       5  28-Jan-17
# 53131   "Significantly improved my quality of life wit...       9  21-Jan-11
# 159679  "I started this Drug in 2004 because because o...      10   1-Apr-16
# 34695   "I&#039;ve had this for a month- perfect. No p...      10   2-Jul-17
# 17217   "I have had pain for 10 years. Since taking Cy...      10  24-Jan-11
#
#         usefulCount
# 52819            26
# 14155             1
# 28608             0
# 47919            31
# 78384            31
# 88297             1
# 53131             8
# 159679           25
# 34695             1
# 17217            22

# %% [markdown]
# From initial observation, I can say that condition and review column consists of invalid char so it need to be cleaned

# %% [markdown]
# ## Basic anaysis

# %%
df.shape
# Out:
# (215063, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 215063 entries, 0 to 53765
# Data columns (total 7 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   uniqueID     215063 non-null  int64
#  1   drugName     215063 non-null  object
#  2   condition    213869 non-null  object
#  3   review       215063 non-null  object
#  4   rating       215063 non-null  int64
#  5   date         215063 non-null  object
#  6   usefulCount  215063 non-null  int64
# dtypes: int64(3), object(4)
# memory usage: 13.1+ MB

# %% [markdown]
# Data column is in string format. It need to be converted into date format

# %%
df.describe()
# Out:
#             uniqueID         rating    usefulCount
# count  215063.000000  215063.000000  215063.000000
# mean   116039.364814       6.990008      28.001004
# std     67007.913366       3.275554      36.346069
# min         0.000000       1.000000       0.000000
# 25%     58115.500000       5.000000       6.000000
# 50%    115867.000000       8.000000      16.000000
# 75%    173963.500000      10.000000      36.000000
# max    232291.000000      10.000000    1291.000000

# %%
df.isnull().sum()
# Out:
# uniqueID          0
# drugName          0
# condition      1194
# review            0
# rating            0
# date              0
# usefulCount       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# There are 1194 rows are null values in condition column

# %%
df.corr(numeric_only=True)
# Out:
#              uniqueID    rating  usefulCount
# uniqueID     1.000000  0.016336     0.017567
# rating       0.016336  1.000000     0.234860
# usefulCount  0.017567  0.234860     1.000000

# %% [markdown]
# ## Univariate analysis

# %%
from wordcloud import WordCloud, STOPWORDS

# %%
wordcloud = WordCloud(stopwords=set(STOPWORDS),
                      background_color='rgb(73, 252, 243)',
                      height=800,
                      width=1000
).generate(str(df['drugName']))


plt.figure(figsize=(10,10))
plt.title('Word Cloud (Drug Names)', fontsize = 10)
plt.axis("off")
plt.imshow(wordcloud)

# %% [markdown]
# The above cloud includes the metadata as well like dtype, Length etc. Because the str(pd.Series) includes meta data as well

# %%
wordcloud = WordCloud(stopwords=set(STOPWORDS),
                      background_color='rgb(73, 252, 243)',
                      height=800,
                      width=1000
).generate(str(df['condition']))


plt.figure(figsize=(10,10))
plt.title('Word Cloud (condition)', fontsize = 10)
plt.axis("off")
plt.imshow(wordcloud)

# %% [markdown]
# Most of the times, we can see the birth control, ADHD, Ventricular etc

# %%
df['rating'].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
sns.kdeplot(df['rating'])
# Out:
# <Axes: xlabel='rating', ylabel='Density'>

# %% [markdown]
# Most of the ratings are higher ratings ie 10, 9, 8. Some drugs about 13% also got worst rating 1

# %%
print((df['rating'] > 5).sum())
print((df['rating'] <= 5).sum())
# Out:
# 150768
# 64295

# %% [markdown]
# Data is imbalance by a huge difference. May be the data includes so much of positive drugs. Hence the model may not perform well on negative drugs so well

# %% [markdown]
# ## Bivariante analysis

# %%
top_drugs_10 = df[df['rating'] == 10]['drugName'].value_counts().head(20)
bar=sns.barplot(top_drugs_10)
bar.set_title('Top 20 drugs whose having 10 rating')
bar.set_xticklabels(bar.get_xticklabels(), rotation=90, ha='right')
sns.set(style = 'darkgrid', font_scale = 1.3)
plt.rcParams['figure.figsize'] = [17, 5]
# Out:
# C:\Users\91939\AppData\Local\Temp\ipykernel_21792\3663489246.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   bar.set_xticklabels(bar.get_xticklabels(), rotation=90, ha='right')

# %%
top_drugs_1 = df[df['rating'] == 1]['drugName'].value_counts().head(20)
bar=sns.barplot(top_drugs_1)
bar.set_title('Top 20 drugs whose having 1 rating')
bar.set_xticklabels(bar.get_xticklabels(), rotation=90, ha='right')
sns.set(style = 'darkgrid', font_scale = 1.3)
plt.rcParams['figure.figsize'] = [8, 8]
# Out:
# C:\Users\91939\AppData\Local\Temp\ipykernel_21792\1902578690.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   bar.set_xticklabels(bar.get_xticklabels(), rotation=90, ha='right')

# %%
top_conditions = df['condition'].value_counts().head(20)
bar=sns.barplot(top_conditions)
bar.set_title('Top conditions')
bar.set_xticklabels(bar.get_xticklabels(), rotation=90, ha='right')
sns.set(style = 'darkgrid', font_scale = 1.3)
plt.rcParams['figure.figsize'] = [5, 5]
# Out:
# C:\Users\91939\AppData\Local\Temp\ipykernel_21792\4106974381.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   bar.set_xticklabels(bar.get_xticklabels(), rotation=90, ha='right')

# %% [markdown]
# ### visualizing as per date

# %%
df['date'] = pd.to_datetime(df['date'])
# Out:
# C:\Users\91939\AppData\Local\Temp\ipykernel_21792\3532345252.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['date'] = pd.to_datetime(df['date'])

# %%
df['year']=df['date'].dt.year
df['month']=df['date'].dt.month
df['day']=df['date'].dt.day

# %%
df.head(2)
# Out:
#    uniqueID    drugName                     condition  \
# 0    206461   Valsartan  Left Ventricular Dysfunction
# 1     95260  Guanfacine                          ADHD
#
#                                               review  rating       date  \
# 0  "It has no side effect, I take it in combinati...       9 2012-05-20
# 1  "My son is halfway through his fourth week of ...       8 2010-04-27
#
#    usefulCount  year  month  day
# 0           27  2012      5   20
# 1          192  2010      4   27

# %%
rating=df.groupby('year')['rating'].mean()
rating.plot(kind='bar',figsize=(10,5),color='green')
plt.title('Mean rating in a year')
# Out:
# Text(0.5, 1.0, 'Mean rating in a year')

# %%
rating=df.groupby('month')['rating'].mean()
rating.plot(kind='bar',figsize=(10,5),color='green')
plt.title('Mean rating in a month')
# Out:
# Text(0.5, 1.0, 'Mean rating in a month')

# %%
rating=df.groupby('day')['rating'].mean()
rating.plot(kind='bar',figsize=(10,5),color='green')
plt.title('Mean rating in a day')
# Out:
# Text(0.5, 1.0, 'Mean rating in a day')

# %% [markdown]
# As we seen the data is distributed equally across the year, month and day. So no need of date column

# %% [markdown]
# ### Usefull count visualization

# %%
df["usefulCount"].describe()
# Out:
# count    215063.000000
# mean         28.001004
# std          36.346069
# min           0.000000
# 25%           6.000000
# 50%          16.000000
# 75%          36.000000
# max        1291.000000
# Name: usefulCount, dtype: float64

# %% [markdown]
# As we see the stdev is so high and the data distribution is so large. So normalizing it will helpfull

# %%
df['usefulCount'].nunique()
# Out:
# 397

# %%
plt.figure(figsize=(14,6))
sns.distplot(df["usefulCount"],color="green")
plt.xticks(rotation='vertical')
plt.xlabel('', fontsize=12)
plt.ylabel('', fontsize=12)
plt.title("Distribution of usefulCount")
# Out:
# C:\Users\91939\AppData\Local\Temp\ipykernel_21792\2665249276.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["usefulCount"],color="green")
# Text(0.5, 1.0, 'Distribution of usefulCount')

# %% [markdown]
# ## Text preprocessing

# %% [markdown]
# #### Droping null values

# %%
df=df.dropna(how="any", axis=0)

# %%
import re
def process(text):
    cleaned_text = re.sub(re.compile('<.*?>'), '', text) #removes html tags
    cleaned_text = cleaned_text.lower() #lowers the data
    cleaned_text = cleaned_text.replace(r'[^\w\d\s]',' ') #removes the special characters
    cleaned_text = cleaned_text.replace(r'[^\x00-\x7F]+',' ') # remove all non aschi values
    cleaned_text = cleaned_text.strip() #removes trailing and leading spaces
    cleaned_text = cleaned_text.replace(r'\s+',' ') # replace multiple spaces with single one
    cleaned_text = cleaned_text.replace(r'\.{2,}', ' ') # replace multiple . with single
    cleaned_text = cleaned_text.replace("&#039;", "") #remove repeating pattern
    
    return cleaned_text

# %% [markdown]
# ### condition series preprocessing

# %%
df['condition'] = df['condition'].apply(process)

# %%
df['review'] = df['review'].apply(process)

# %%
df.sample(20)
# Out:
#         uniqueID                           drugName  \
# 87582     175193                        Linaclotide
# 25853      21197             Multivitamin with iron
# 151418     62890                           Fortesta
# 81420     225845                          Bupropion
# 54070      32987                         Seasonique
# 61302     151845                            Chantix
# 61886     111070                          Verapamil
# 98582      58732  Hydrochlorothiazide / telmisartan
# 36741      96345                         Sertraline
# 3751      191123                            Campral
# 10594     117808         Multivitamin with minerals
# 119653    187028                        Famciclovir
# 10054      94078                         Trintellix
# 123583    178905                            Victoza
# 31545      26939                             Ultram
# 126791    105952                        Atomoxetine
# 34345     222572                            Kyleena
# 49593      21606                       Pitavastatin
# 22931     194431                            Crestor
# 32154     210710                        Mirtazapine
#
#                                              condition  \
# 87582                                     constipation
# 25853                                           anemia
# 151418                              hypogonadism, male
# 81420                                  bipolar disorde
# 54070                                    birth control
# 61302                                smoking cessation
# 61886                                cluster headaches
# 98582                              high blood pressure
# 36741                               anxiety and stress
# 3751                                alcohol dependence
# 10594   vitamin/mineral supplementation and deficiency
# 119653                     herpes simplex, suppression
# 10054                                       depression
# 123583                                diabetes, type 2
# 31545                                             pain
# 126791                                            adhd
# 34345                                    birth control
# 49593                                 high cholesterol
# 22931                                 high cholesterol
# 32154                                       depression
#
#                                                    review  rating       date  \
# 87582   "day three of 290 linzess and nothing!  x-rays...       1 2013-04-11
# 25853                                          "helpful!"      10 2013-05-01
# 151418  "worked well and fast, easy to use, no stank, ...       9 2013-10-01
# 81420   "i have taken wellbutrin sr for about 8 months...       9 2010-08-09
# 54070   "i have been so happy on this medication. i ac...       9 2012-04-18
# 61302   "smoked for 20 years, quit for 4 years, smoked...      10 2013-04-05
# 61886   "im a 56 year old male and started having ch a...       4 2015-12-10
# 98582   "very satisfied, ive been using micardis plus ...      10 2017-04-27
# 36741   "i started using zoloft for anxiety and minor ...       9 2009-09-09
# 3751                                          "it works."       9 2008-12-17
# 10594   "i was told to take preservision areds 2 after...       2 2017-05-06
# 119653  "famvir works the best. i have a lot less brea...      10 2008-07-22
# 10054   "i was about to give up on this med because of...       5 2016-05-18
# 123583  "my blood sugar was between 140 - 160 with bot...       9 2011-12-31
# 31545   "have periodic leg and foot pain due to being ...       8 2014-03-21
# 126791  "my son who is 12 has been on this medication ...       1 2016-02-03
# 34345   "21 years old and no kids. approx 120 lbs. i g...       7 2017-05-16
# 49593   "i tried 2 different statins that caused me ho...       1 2017-03-17
# 22931   "crestor was doing a very good job in bringing...       5 2011-08-20
# 32154   "this medication was the magic bullet for me a...       9 2017-03-24
#
#         usefulCount  year  month  day
# 87582            47  2013      4   11
# 25853             9  2013      5    1
# 151418           22  2013     10    1
# 81420            35  2010      8    9
# 54070            20  2012      4   18
# 61302            26  2013      4    5
# 61886            12  2015     12   10
# 98582             0  2017      4   27
# 36741            57  2009      9    9
# 3751             29  2008     12   17
# 10594             6  2017      5    6
# 119653           47  2008      7   22
# 10054            72  2016      5   18
# 123583           11  2011     12   31
# 31545            43  2014      3   21
# 126791           15  2016      2    3
# 34345             0  2017      5   16
# 49593            17  2017      3   17
# 22931            59  2011      8   20
# 32154            46  2017      3   24

# %% [markdown]
# After doing the preprocessing, in some reviews we find \r, \n and emojis and @amp for and . So remove them also

# %%
emoji_pattern = re.compile(
    "["
    u"\U0001F600-\U0001F64F"
    u"\U0001F300-\U0001F5FF"
    u"\U0001F680-\U0001F6FF"
    u"\U0001F1E0-\U0001F1FF"
    "]+",
    flags=re.UNICODE,
)

# %%
df['review'] = (df['review'].str.replace(r'[\n\r]+', ' ', regex=True).str.replace(emoji_pattern, '', regex=True))

# %%
df['review'] = df['review'].str.replace('&amp;', 'and', regex=True)
df['review'] = df['review'].str.replace('&quot;', 'and', regex=True)

# %%
df.sample(20)
# Out:
#         uniqueID                          drugName                 condition  \
# 36032     178687                           Victoza               weight loss
# 65368     124342                             Skyla             birth control
# 79997     105872                       Atomoxetine                      adhd
# 40489     177833                        Duloxetine                 back pain
# 12583      85370  Ethinyl estradiol / norgestimate             birth control
# 18031     148866                            Mirena             birth control
# 26517     126394                       Naphazoline          nasal congestion
# 115970    163043                          Decadron         allergic rhinitis
# 12164     210414                           Linzess  irritable bowel syndrome
# 51677      44487  Ethinyl estradiol / norgestimate             birth control
# 120666     63625                            Epiduo                      acne
# 131337     44369  Ethinyl estradiol / norgestimate             birth control
# 117237    192004  Drospirenone / ethinyl estradiol                      acne
# 148199     43010                         Phenytoin                  epilepsy
# 18293     206530                         Valsartan       high blood pressure
# 27334      97302                            Ambien                  insomnia
# 30811       4001                       Risedronate              osteoporosis
# 50072     228468                            Geodon           bipolar disorde
# 43463     180249                        Diclofenac            osteoarthritis
# 42351     162199                         Denosumab              osteoporosis
#
#                                                    review  rating       date  \
# 36032   "ive been on the drug for about 10 months.  lo...       8 2016-09-01
# 65368   "today, i had the skyla inserted in me. it too...       6 2016-01-09
# 79997   "so ive been using strattera 40-50-60mg since ...       5 2017-07-18
# 40489   "ive been taking 60mg for 2 years for back pai...       8 2013-06-06
# 12583   "i was on this pill for a little more than one...       7 2015-05-30
# 18031   "just had it inserted today and it was pretty ...       6 2015-11-24
# 26517   "i wish they would bring this back to the mark...      10 2014-04-14
# 115970  "although i have to go to the doctor and get a...      10 2010-02-09
# 12164   "i am 37 year old female who has been sufferin...       8 2014-02-15
# 51677   "i didnt like this birth control at all. i hav...       5 2009-11-01
# 120666  "this stuff is amazing! at first i had my doub...      10 2014-10-09
# 131337  "im 19 and have been on this pill for two mont...       4 2010-09-13
# 117237  "im a healthy 20 year old with no history of b...       2 2016-11-20
# 148199  "i have had good but not great response with d...       7 2010-04-19
# 18293   "i have been taking this drugs for a few month...       3 2017-03-25
# 27334   "helps me sleep through the night for the firs...      10 2009-12-26
# 30811   "i took actonel for 7 months. im 55 yrs young ...       4 2011-05-08
# 50072   "this causes crazy weight gain. i was 120 now ...       5 2017-01-18
# 43463   "cant even open the tube. have a friend with s...       1 2017-12-10
# 42351   "i had 2 shots (1 every 6 months) for 2 years,...      10 2015-12-28
#
#         usefulCount  year  month  day
# 36032            65  2016      9    1
# 65368             0  2016      1    9
# 79997            13  2017      7   18
# 40489             3  2013      6    6
# 12583            11  2015      5   30
# 18031             2  2015     11   24
# 26517            23  2014      4   14
# 115970           15  2010      2    9
# 12164            76  2014      2   15
# 51677             1  2009     11    1
# 120666           62  2014     10    9
# 131337            4  2010      9   13
# 117237            5  2016     11   20
# 148199           14  2010      4   19
# 18293            21  2017      3   25
# 27334            39  2009     12   26
# 30811           103  2011      5    8
# 50072            14  2017      1   18
# 43463             0  2017     12   10
# 42351            83  2015     12   28

# %% [markdown]
# Now the review and conditions looks good

# %% [markdown]
# ## Feature Engineering

# %%
df.drop(columns=['date','year','month','day','uniqueID'],inplace=True)

# %%
df.sample()
# Out:
#      drugName    condition                                             review  \
# 8664  Savella  ibromyalgia  "the pain is down, but i am having trouble sle...
#
#       rating  usefulCount
# 8664       7           13

# %%
df['sentiment'] = df["rating"].apply(lambda x: 1 if x > 5 else 0)

# %%
df.sample(5)
# Out:
#             drugName        condition  \
# 66219   Voltaren Gel             pain
# 10692       Tramadol             pain
# 121968  Depo-Provera    birth control
# 3369      Quetiapine  bipolar disorde
# 53738     Diclofenac             pain
#
#                                                    review  rating  \
# 66219   "was using this for achilles micro tears from ...       6
# 10692   "made me very ill after one tablet. vomiting f...       2
# 121968  "i have used many types of birth controls from...       6
# 3369    "when i was first put on this medication in th...      10
# 53738   "this drug is an excellent anti-inflammatory. ...       4
#
#         usefulCount  sentiment
# 66219            35          1
# 10692             8          0
# 121968            2          1
# 3369             53          1
# 53738             9          0

# %% [markdown]
# #### Feature representation

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\91939\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords

sw_list = stopwords.words('english')
df['review'] = df['review'].apply(lambda x: [item for item in x.split() if item not in sw_list]).apply(lambda x:" ".join(x))

# %%
df.sample(5)
# Out:
#                                 drugName      condition  \
# 24465                          Buspirone        anxiety
# 117966                           Intuniv           adhd
# 136688                       Fluticasone       rhinitis
# 12953    Desogestrel / ethinyl estradiol  birth control
# 92969   Drospirenone / ethinyl estradiol  birth control
#
#                                                    review  rating  \
# 24465   "i tried buspar addition 200mg zoloft. meant e...       3
# 117966  "im add, h included. 11 year old daughter also...       1
# 136688  "great product using 10 years. smoker using pr...       9
# 12953   "id say good/decent pill overall, pills decide...       9
# 92969   "i used yaz years problems gianvi made moody, ...       1
#
#         usefulCount  sentiment
# 24465            27          0
# 117966           93          0
# 136688           19          1
# 12953             1          1
# 92969             5          0

# %%
df.loc[df['condition'] == '0 users found this comment helpful.'].shape
# Out:
# (128, 6)

# %%
df['condition'] = df['condition'].str.replace('0 users found this comment helpful.', 'Not Specified', regex=True)

# %%
df.loc[df['condition'] == 'Not Specified'].head(3)
# Out:
#                 drugName      condition  \
# 516       Nortrel 1 / 35  Not Specified
# 553       Loestrin 24 Fe  Not Specified
# 571  Ortho Tri-Cyclen Lo  Not Specified
#
#                                                 review  rating  usefulCount  \
# 516  "they switched necon nortrel saying andsameand...       2            0
# 553  "i loestrin 24 fe 6 months never problems emot...       7            0
# 571  "i love birth control spotting periods. little...       9            0
#
#      sentiment
# 516          0
# 553          1
# 571          1

# %%
# !pip install textblob
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: textblob in c:\users\91939\appdata\roaming\python\python312\site-packages (0.19.0)
# Requirement already satisfied: nltk>=3.9 in c:\users\91939\appdata\roaming\python\python312\site-packages (from textblob) (3.9.1)
# Requirement already satisfied: click in c:\users\91939\appdata\roaming\python\python312\site-packages (from nltk>=3.9->textblob) (8.1.8)
# Requirement already satisfied: joblib in c:\users\91939\appdata\roaming\python\python312\site-packages (from nltk>=3.9->textblob) (1.1.1)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\91939\appdata\roaming\python\python312\site-packages (from nltk>=3.9->textblob) (2024.11.6)
# Requirement already satisfied: tqdm in c:\users\91939\appdata\roaming\python\python312\site-packages (from nltk>=3.9->textblob) (4.67.1)
# Requirement already satisfied: colorama in c:\users\91939\appdata\roaming\python\python312\site-packages (from click->nltk>=3.9->textblob) (0.4.6)
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from nltk.stem import SnowballStemmer
from textblob import TextBlob

# %%
Snow_ball = SnowballStemmer("english")
df['review'] = df['review'].apply(lambda x: " ".join(Snow_ball.stem(word) for word in x.split()))

# %%
df.sample(3)
# Out:
#             drugName        condition  \
# 75135  Blisovi 24 Fe    birth control
# 50781          Aleve        back pain
# 76453      Trileptal  bipolar disorde
#
#                                                   review  rating  usefulCount  \
# 75135  "ive experienc exact other comment here. fine ...       1            3
# 50781  "not good thc effect me. one want solut allow ...       9           20
# 76453  "after reaction lamict topamax- trilept didnt ...       9           46
#
#        sentiment
# 75135          0
# 50781          1
# 76453          1

# %%
# to determine the polarity of the review
def sentiment(review):
    pol = []
    for i in review:
        analysis = TextBlob(i)
        pol.append(analysis.sentiment.polarity)
    return pol

# %%
df['review_sentiment'] = sentiment(df['review'])

# %%
df.sample(10)
# Out:
#                drugName                 condition  \
# 29069   Cyclobenzaprine              muscle spasm
# 36300            Avelox       bacterial infection
# 8069            Mucinex               ibromyalgia
# 33159          Cymbalta  major depressive disorde
# 47961            Xulane             birth control
# 37561        Cevimeline        sjogren's syndrome
# 67302               Yaz             birth control
# 23555          Losartan       high blood pressure
# 59652       Mirtazapine                   anxiety
# 132789      Varenicline         smoking cessation
#
#                                                    review  rating  \
# 29069   "i take flexeril muscl spasm back. would relia...       5
# 36300   "mi second time take avelox pneumonia. benefit...       8
# 8069    "i diagnos 20 put muscl relax pain killer noth...      10
# 33159   "i use cymbalta 60mg night. sleep better, eat ...       9
# 47961   "the patch caus itchi goe away. notic breast f...       7
# 37561   "while take evoxac sever bodi odor, genit smel...       1
# 67302   "i actual love yaz. wasnt moodi lost 20 lbs it...       9
# 23555   "took losartan 50 mg three days. im experienc ...       1
# 59652   "at first remeron amazing. felt much better sh...       6
# 132789  "2nd time use chantix. work first work time! n...      10
#
#         usefulCount  sentiment  review_sentiment
# 29069            43          0          0.000000
# 36300             9          1         -0.120833
# 8069            145          1          0.000000
# 33159            40          1          0.325298
# 47961             4          1          0.487500
# 37561             9          0          0.097727
# 67302             8          1          0.052083
# 23555            47          0          0.000000
# 59652            74          1          0.170000
# 132789           19          1          0.195312

# %%
df.corr(numeric_only=True)
# Out:
#                     rating  usefulCount  sentiment  review_sentiment
# rating            1.000000     0.235121   0.916406          0.287993
# usefulCount       0.235121     1.000000   0.212763          0.073422
# sentiment         0.916406     0.212763   1.000000          0.261538
# review_sentiment  0.287993     0.073422   0.261538          1.000000

# %%
import nltk
nltk.download('punkt_tab')
from nltk import sent_tokenize
import gensim
from gensim.utils import simple_preprocess
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\91939\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.

# %%
df['tokens'] = df['review'].apply(simple_preprocess)

# %%
from gensim.models import Word2Vec

sentences = df['tokens'].tolist()

w2v_model = Word2Vec(
    sentences=sentences,
    vector_size=100,
    window=5,
    min_count=2,
    workers=4
)

# %%
w2v_model.train(sentences,total_examples=w2v_model.corpus_count,epochs=w2v_model.epochs)
# Out:
# (40958989, 46130600)
