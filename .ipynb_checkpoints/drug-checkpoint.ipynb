# %% [markdown]
# ## Data Aggrigation

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_train = pd.read_csv('drugsComTrain_raw.csv')
df_test = pd.read_csv('drugsComTest_raw.csv')

# %%
data = pd.concat([df_train,df_test])

# %%
data.sample(5)
# Out:
#         uniqueID    drugName               condition  \
# 143068    182891    Cymbalta                 Anxiety
# 141068     38198   Albuterol             COPD, Acute
# 43140      89458      Celexa              Depression
# 47656     117772      Aldara    Basal Cell Carcinoma
# 91858     156328  Ropinirole  Restless Legs Syndrome
#
#                                                    review  rating       date  \
# 143068  "Was prescribed for depression, but it affecte...       8  11-Apr-16
# 141068  "Getting a lot of blisters on my top of my han...       5   1-Aug-16
# 43140   "On Day 1.  Felt a little out of it but some h...       9   6-Jan-13
# 47656   "Second time on Aldra.  The first time I used ...      10  20-Aug-17
# 91858   "This medicine has worked great for me and bee...      10  12-Apr-15
#
#         usefulCount
# 143068           67
# 141068            2
# 43140            44
# 47656             6
# 91858            14

# %%
df = data.copy()

# %%
df.sample(10)
# Out:
#         uniqueID                           drugName  \
# 29154      18586                        Alendronate
# 64879      73297  Ethinyl estradiol / norethindrone
# 36678     140609                       Escitalopram
# 85503      69862                            Tylenol
# 15891     159327                            Januvia
# 42704     153734                        Doxycycline
# 8175      125807                            Viibryd
# 922       132464                            Doxepin
# 129000      6983      Aluminum chloride hexahydrate
# 31261      37103                           Zepatier
#
#                           condition  \
# 29154    Prevention of Osteoporosis
# 64879     Polycystic Ovary Syndrome
# 36678   Generalized Anxiety Disorde
# 85503                          Pain
# 15891              Diabetes, Type 2
# 42704                       Rosacea
# 8175                     Depression
# 922                      Depression
# 129000                Hyperhidrosis
# 31261                   Hepatitis C
#
#                                                    review  rating       date  \
# 29154   "Joint pain, back pain, involuntary jerking, s...       2  28-Feb-17
# 64879   "No menstrual at all. No cramps or bloating. W...      10  24-Apr-14
# 36678   "I first went on Lexapro 10mg in 2010. I was p...       2   1-Feb-17
# 85503   "I would take two 500mg pills once a day. I us...       8  15-Mar-15
# 15891   "This drug came after a bad reaction to Metfor...       1  16-Apr-16
# 42704   "Here&#039;s the issue, my rosacea abated for ...       6  26-Jul-09
# 8175    "Tried Viibryd about 3 years ago after trying ...       4  28-Mar-17
# 922     "This stuff garbage woke up hyper and shortnes...       1   3-Aug-17
# 129000  "You won&#039;t believe this, but I decided to...      10  30-Aug-15
# 31261   "I am a 20 year old female, one of the younges...       5   3-Jun-17
#
#         usefulCount
# 29154            13
# 64879            20
# 36678             9
# 85503            18
# 15891            32
# 42704            27
# 8175             18
# 922               6
# 129000            9
# 31261             8

# %% [markdown]
# From initial observation, I can say that condition and review column consists of invalid char so it need to be cleaned

# %% [markdown]
# ## Basic anaysis

# %%
df.shape
# Out:
# (215063, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 215063 entries, 0 to 53765
# Data columns (total 7 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   uniqueID     215063 non-null  int64
#  1   drugName     215063 non-null  object
#  2   condition    213869 non-null  object
#  3   review       215063 non-null  object
#  4   rating       215063 non-null  int64
#  5   date         215063 non-null  object
#  6   usefulCount  215063 non-null  int64
# dtypes: int64(3), object(4)
# memory usage: 13.1+ MB

# %% [markdown]
# Data column is in string format. It need to be converted into date format

# %%
df.describe()
# Out:
#             uniqueID         rating    usefulCount
# count  215063.000000  215063.000000  215063.000000
# mean   116039.364814       6.990008      28.001004
# std     67007.913366       3.275554      36.346069
# min         0.000000       1.000000       0.000000
# 25%     58115.500000       5.000000       6.000000
# 50%    115867.000000       8.000000      16.000000
# 75%    173963.500000      10.000000      36.000000
# max    232291.000000      10.000000    1291.000000

# %%
df.isnull().sum()
# Out:
# uniqueID          0
# drugName          0
# condition      1194
# review            0
# rating            0
# date              0
# usefulCount       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# There are 1194 rows are null values in condition column

# %%
df.corr(numeric_only=True)
# Out:
#              uniqueID    rating  usefulCount
# uniqueID     1.000000  0.016336     0.017567
# rating       0.016336  1.000000     0.234860
# usefulCount  0.017567  0.234860     1.000000

# %% [markdown]
# ## Univariate analysis

# %%
from wordcloud import WordCloud, STOPWORDS

# %%
wordcloud = WordCloud(stopwords=set(STOPWORDS),
                      background_color='rgb(73, 252, 243)',
                      height=800,
                      width=1000
).generate(str(df['drugName']))


plt.figure(figsize=(10,10))
plt.title('Word Cloud (Drug Names)', fontsize = 10)
plt.axis("off")
plt.imshow(wordcloud)

# %% [markdown]
# The above cloud includes the metadata as well like dtype, Length etc. Because the str(pd.Series) includes meta data as well

# %%
wordcloud = WordCloud(stopwords=set(STOPWORDS),
                      background_color='rgb(73, 252, 243)',
                      height=800,
                      width=1000
).generate(str(df['condition']))


plt.figure(figsize=(10,10))
plt.title('Word Cloud (condition)', fontsize = 10)
plt.axis("off")
plt.imshow(wordcloud)

# %% [markdown]
# Most of the times, we can see the birth control, ADHD, Ventricular etc

# %%
df['rating'].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
sns.kdeplot(df['rating'])
# Out:
# <Axes: xlabel='rating', ylabel='Density'>

# %% [markdown]
# Most of the ratings are higher ratings ie 10, 9, 8. Some drugs about 13% also got worst rating 1

# %%
print((df['rating'] > 5).sum())
print((df['rating'] <= 5).sum())
# Out:
# 150768
# 64295

# %% [markdown]
# Data is imbalance by a huge difference. May be the data includes so much of positive drugs. Hence the model may not perform well on negative drugs so well

# %% [markdown]
# ## Bivariante analysis

# %%
top_drugs_10 = df[df['rating'] == 10]['drugName'].value_counts().head(20)
bar=sns.barplot(top_drugs_10)
bar.set_title('Top 20 drugs whose having 10 rating')
bar.set_xticklabels(bar.get_xticklabels(), rotation=90, ha='right')
sns.set(style = 'darkgrid', font_scale = 1.3)
plt.rcParams['figure.figsize'] = [17, 5]
# Out:
# C:\Users\91939\AppData\Local\Temp\ipykernel_3704\3663489246.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   bar.set_xticklabels(bar.get_xticklabels(), rotation=90, ha='right')

# %%
top_drugs_1 = df[df['rating'] == 1]['drugName'].value_counts().head(20)
bar=sns.barplot(top_drugs_1)
bar.set_title('Top 20 drugs whose having 1 rating')
bar.set_xticklabels(bar.get_xticklabels(), rotation=90, ha='right')
sns.set(style = 'darkgrid', font_scale = 1.3)
plt.rcParams['figure.figsize'] = [8, 8]
# Out:
# C:\Users\91939\AppData\Local\Temp\ipykernel_3704\1902578690.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   bar.set_xticklabels(bar.get_xticklabels(), rotation=90, ha='right')

# %%
top_conditions = df['condition'].value_counts().head(20)
bar=sns.barplot(top_conditions)
bar.set_title('Top conditions')
bar.set_xticklabels(bar.get_xticklabels(), rotation=90, ha='right')
sns.set(style = 'darkgrid', font_scale = 1.3)
plt.rcParams['figure.figsize'] = [5, 5]
# Out:
# C:\Users\91939\AppData\Local\Temp\ipykernel_3704\4106974381.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   bar.set_xticklabels(bar.get_xticklabels(), rotation=90, ha='right')

# %% [markdown]
# ### visualizing as per date

# %%
df['date'] = pd.to_datetime(df['date'])
# Out:
# C:\Users\91939\AppData\Local\Temp\ipykernel_3704\3532345252.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['date'] = pd.to_datetime(df['date'])

# %%
df['year']=df['date'].dt.year
df['month']=df['date'].dt.month
df['day']=df['date'].dt.day

# %%
df.head(2)
# Out:
#    uniqueID    drugName                     condition  \
# 0    206461   Valsartan  Left Ventricular Dysfunction
# 1     95260  Guanfacine                          ADHD
#
#                                               review  rating       date  \
# 0  "It has no side effect, I take it in combinati...       9 2012-05-20
# 1  "My son is halfway through his fourth week of ...       8 2010-04-27
#
#    usefulCount  year  month  day
# 0           27  2012      5   20
# 1          192  2010      4   27

# %%
rating=df.groupby('year')['rating'].mean()
rating.plot(kind='bar',figsize=(10,5),color='green')
plt.title('Mean rating in a year')
# Out:
# Text(0.5, 1.0, 'Mean rating in a year')

# %%
rating=df.groupby('month')['rating'].mean()
rating.plot(kind='bar',figsize=(10,5),color='green')
plt.title('Mean rating in a month')
# Out:
# Text(0.5, 1.0, 'Mean rating in a month')

# %%
rating=df.groupby('day')['rating'].mean()
rating.plot(kind='bar',figsize=(10,5),color='green')
plt.title('Mean rating in a day')
# Out:
# Text(0.5, 1.0, 'Mean rating in a day')

# %% [markdown]
# As we seen the data is distributed equally across the year, month and day. So no need of date column

# %% [markdown]
# ### Usefull count visualization

# %%
df["usefulCount"].describe()
# Out:
# count    215063.000000
# mean         28.001004
# std          36.346069
# min           0.000000
# 25%           6.000000
# 50%          16.000000
# 75%          36.000000
# max        1291.000000
# Name: usefulCount, dtype: float64

# %% [markdown]
# As we see the stdev is so high and the data distribution is so large. So normalizing it will helpfull

# %%
df['usefulCount'].nunique()
# Out:
# 397

# %%
plt.figure(figsize=(14,6))
sns.distplot(df["usefulCount"],color="green")
plt.xticks(rotation='vertical')
plt.xlabel('', fontsize=12)
plt.ylabel('', fontsize=12)
plt.title("Distribution of usefulCount")
# Out:
# C:\Users\91939\AppData\Local\Temp\ipykernel_3704\2665249276.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["usefulCount"],color="green")
# Text(0.5, 1.0, 'Distribution of usefulCount')

# %% [markdown]
# ## Text preprocessing

# %% [markdown]
# #### Droping null values

# %%
df=df.dropna(how="any", axis=0)

# %%
import re
def process(text):
    cleaned_text = re.sub(re.compile('<.*?>'), '', text) #removes html tags
    cleaned_text = cleaned_text.lower() #lowers the data
    cleaned_text = cleaned_text.replace(r'[^\w\d\s]',' ') #removes the special characters
    cleaned_text = cleaned_text.replace(r'[^\x00-\x7F]+',' ') # remove all non aschi values
    cleaned_text = cleaned_text.strip() #removes trailing and leading spaces
    cleaned_text = cleaned_text.replace(r'\s+',' ') # replace multiple spaces with single one
    cleaned_text = cleaned_text.replace(r'\.{2,}', ' ') # replace multiple . with single
    cleaned_text = cleaned_text.replace("&#039;", "") #remove repeating pattern
    
    return cleaned_text

# %% [markdown]
# ### condition series preprocessing

# %%
df['condition'] = df['condition'].apply(process)

# %%
df['review'] = df['review'].apply(process)

# %%
df.sample(20)
# Out:
#         uniqueID                         drugName                 condition  \
# 107061    150543  Sulfamethoxazole / trimethoprim   urinary tract infection
# 2602      109236                        Nexplanon             birth control
# 91632     124825                     Tri-Previfem             birth control
# 80628     183407                         Cymbalta           bipolar disorde
# 72281      40041                         Contrave                   obesity
# 39352     189822                   Chlorpromazine                   hiccups
# 159113    225216                        Bupropion  major depressive disorde
# 141371    133396                        Soolantra                   rosacea
# 93394     115969                Divalproex sodium                  epilepsy
# 140608    229163                        Tadalafil      erectile dysfunction
# 21114      71212                          Lysteda               menorrhagia
# 143136      2035                        Metformin          diabetes, type 2
# 40792     143446                     Etonogestrel             birth control
# 86660     179999     Adapalene / benzoyl peroxide                      acne
# 50048     112682                          Lunesta                  insomnia
# 7941       58121      Acetaminophen / hydrocodone                      pain
# 110009     98046                        Nexplanon             birth control
# 889       112524                          Lunesta                  insomnia
# 20546      77749                     Moxifloxacin       bacterial infection
# 61969     175027                       Fingolimod        multiple sclerosis
#
#                                                    review  rating       date  \
# 107061  "i was scared to take this because i read abou...       7 2016-06-06
# 2602    "i am 28 y.o. and had nexplannon inserted marc...       3 2017-02-23
# 91632   "i have been using this birth control for a li...       1 2015-11-17
# 80628   "i have been taking cymbalta for the second ti...       5 2011-11-14
# 72281   "i started taking contrave on 4/20. my startin...       8 2015-05-06
# 39352   "i have been fighting hiccups off and on for w...       5 2015-10-15
# 159113  "i am a 53 year old woman, i have struggled wi...      10 2015-11-26
# 141371  "i used this for my dermatitis. it made it muc...       1 2017-11-18
# 93394   "i was put on depakote originally to control m...       8 2010-03-26
# 140608  "im 40 and have been having issues recently wi...      10 2013-02-12
# 21114   "i have been taking lysteda for 2 months now a...      10 2012-12-27
# 143136  "i began metformin  2 years ago, dosage of 100...       7 2017-10-16
# 40792   "i had the nexaplanon inserted back in 2013 af...      10 2017-01-25
# 86660   "a while ago, i was assured that clinique coul...      10 2013-10-10
# 50048   "i tried ambien but the only thing it did was ...      10 2010-03-12
# 7941    "recently i was put on norco for a hand injury...       8 2009-04-28
# 110009  "i got mine in april 2014, since then i have h...       3 2015-09-05
# 889     "i was taking ambien 15mg for awhile but my bo...       6 2016-09-28
# 20546   "this past wednesday my right nostril was a li...       7 2011-12-27
# 61969   "i was on gilenya (fingolimod) for 6 months, b...       7 2015-04-16
#
#         usefulCount  year  month  day
# 107061           70  2016      6    6
# 2602              1  2017      2   23
# 91632             6  2015     11   17
# 80628            24  2011     11   14
# 72281            34  2015      5    6
# 39352             6  2015     10   15
# 159113           25  2015     11   26
# 141371            0  2017     11   18
# 93394            18  2010      3   26
# 140608           90  2013      2   12
# 21114            58  2012     12   27
# 143136            5  2017     10   16
# 40792             1  2017      1   25
# 86660            16  2013     10   10
# 50048            15  2010      3   12
# 7941             23  2009      4   28
# 110009            4  2015      9    5
# 889              23  2016      9   28
# 20546            10  2011     12   27
# 61969            32  2015      4   16

# %% [markdown]
# After doing the preprocessing, in some reviews we find \r, \n and emojis and @amp for and . So remove them also

# %%
emoji_pattern = re.compile(
    "["
    u"\U0001F600-\U0001F64F"
    u"\U0001F300-\U0001F5FF"
    u"\U0001F680-\U0001F6FF"
    u"\U0001F1E0-\U0001F1FF"
    "]+",
    flags=re.UNICODE,
)

# %%
df['review'] = (df['review'].str.replace(r'[\n\r]+', ' ', regex=True).str.replace(emoji_pattern, '', regex=True))

# %%
df['review'] = df['review'].str.replace('&amp;', 'and', regex=True)
df['review'] = df['review'].str.replace('&quot;', 'and', regex=True)

# %%
df.sample(20)
# Out:
#         uniqueID                           drugName  \
# 49894      22560                             Pylera
# 4342      181528                             Prozac
# 140158    118058                           Apixaban
# 4506      183890                         Mometasone
# 37956      77646                         Cephalexin
# 63680     154705                      Metronidazole
# 73918     121781                        Venlafaxine
# 2801       77532                         Cephalexin
# 125366     73256  Ethinyl estradiol / norethindrone
# 39486      93600                           Morphine
# 22421     200767                        Varenicline
# 14127     121888                        Venlafaxine
# 60714      77055                         Lorcaserin
# 89669     105780                         Cilostazol
# 117774    200138                        Varenicline
# 26682     122745                        Linaclotide
# 48492      72937  Ethinyl estradiol / norethindrone
# 21986      62817                             Cozaar
# 99092      95489                             Otezla
# 124270      3939                        Seroquel XR
#
#                                                 condition  \
# 49894                       helicobacter pylori infection
# 4342                                           depression
# 140158  prevention of thromboembolism in atrial fibril...
# 4506                                    allergic rhinitis
# 37956                                   bladder infection
# 63680                                 bacterial vaginitis
# 73918                                          depression
# 2801                                  bacterial infection
# 125366                                      birth control
# 39486                                        chronic pain
# 22421                                   smoking cessation
# 14127                                             anxiety
# 60714                                         weight loss
# 89669                           intermittent claudication
# 117774                                  smoking cessation
# 26682                            irritable bowel syndrome
# 48492                                       birth control
# 21986                                 high blood pressure
# 99092                                 psoriatic arthritis
# 124270                                    bipolar disorde
#
#                                                    review  rating       date  \
# 49894   "i finished up my 10 days it was extremely dif...       8 2016-11-14
# 4342    "been on fluoxetine for 7 weeks now, i got my ...       6 2014-03-11
# 140158  "i was diagnosed with afibs about 6 years ago....       5 2017-03-10
# 4506    "i went to see my doctor about inflammation to...      10 2009-04-09
# 37956   "works sooo good!  had a uti and after 2 days ...      10 2015-07-16
# 63680   "this medicine works great! my gyno prescribed...       9 2017-07-25
# 73918         "as long as i am on 225 mg i do just fine."      10 2013-12-23
# 2801    "i started taking cephalexin to prevent any ba...       5 2016-11-22
# 125366  "i only tried this pill for barely under 3 wee...       5 2014-07-20
# 39486   "this medication gave me my life back! im 20, ...      10 2015-06-16
# 22421   "i took chantix according to the directions fo...      10 2008-12-27
# 14127   "possibly the best medication i have ever been...      10 2012-12-21
# 60714   "been one week and down 7lbs... i have a sligh...      10 2014-11-05
# 89669   "i was prescribed this after my right side int...      10 2012-01-06
# 117774  "after taking chantix for only a week, i was a...      10 2015-06-12
# 26682   "have had years of irritable bowel syndrome wi...       8 2014-06-22
# 48492   "just checking in again. switched my pill from...       1 2015-05-30
# 21986   "i used 2 tablets of cozaar 25 for 2 weeks wit...       1 2009-07-15
# 99092   "this was the hardest drug to get and be appro...       2 2015-08-15
# 124270  "recently able to get the xr in generic form. ...      10 2017-06-23
#
#         usefulCount  year  month  day
# 49894             5  2016     11   14
# 4342             31  2014      3   11
# 140158           59  2017      3   10
# 4506             30  2009      4    9
# 37956            67  2015      7   16
# 63680            11  2017      7   25
# 73918            31  2013     12   23
# 2801              1  2016     11   22
# 125366           11  2014      7   20
# 39486            67  2015      6   16
# 22421            13  2008     12   27
# 14127            11  2012     12   21
# 60714            42  2014     11    5
# 89669            34  2012      1    6
# 117774           32  2015      6   12
# 26682            69  2014      6   22
# 48492            15  2015      5   30
# 21986            38  2009      7   15
# 99092            19  2015      8   15
# 124270            6  2017      6   23

# %% [markdown]
# Now the review and conditions looks good

# %% [markdown]
# ## Feature Engineering

# %%
df.drop(columns=['date','year','month','day','uniqueID'],inplace=True)

# %%
df.sample()
# Out:
#           drugName condition  \
# 52085  Minocycline      acne
#
#                                                   review  rating  usefulCount
# 52085  "i started taking this medication for a scalp ...       7            5

# %%
df['sentiment'] = df["rating"].apply(lambda x: 1 if x > 5 else 0)

# %%
df.sample(5)
# Out:
#               drugName               condition  \
# 6487            Epiduo                    acne
# 13423   Lo Loestrin Fe           birth control
# 119107  Clarithromycin               sinusitis
# 86842      Terbinafine  onychomycosis, toenail
# 33571      Oxymorphone                    pain
#
#                                                    review  rating  \
# 6487    "made my face 1000x worse than it was. i got a...       1
# 13423   "i just finished my first pack and i love it s...       8
# 119107                                             "good"       9
# 86842   "i am a 35 year old male living in canada and ...      10
# 33571   "serious auto wreck crushed 2 discs in cervica...       8
#
#         usefulCount  sentiment
# 6487              7          0
# 13423             9          1
# 119107            8          1
# 86842            38          1
# 33571             7          1

# %% [markdown]
# #### Feature representation

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\91939\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords

sw_list = stopwords.words('english')
df['review'] = df['review'].apply(lambda x: [item for item in x.split() if item not in sw_list]).apply(lambda x:" ".join(x))

# %%
df.sample(5)
# Out:
#                         drugName                  condition  \
# 37644   Buprenorphine / naloxone          opiate dependence
# 156058                    Mirena  abnormal uterine bleeding
# 73338                 Duloxetine               chronic pain
# 6092                       Norco                       pain
# 53386                    Intuniv                       adhd
#
#                                                    review  rating  \
# 37644   "ok wife zobsolv week now. first seemed, help ...       1
# 156058  "ive mirena 6 weeks heavy prolonged periods. i...       3
# 73338   "was given 30mg cymbalta pain hip well depress...       1
# 6092    "i suffering surgery back went wrong. 2 surger...      10
# 53386   "my adopted 13 y.o. son fetal alcohol syndrome...       8
#
#         usefulCount  sentiment
# 37644             8          0
# 156058            4          0
# 73338            42          0
# 6092             33          1
# 53386            53          1

# %%
df.loc[df['condition'] == '0 users found this comment helpful.'].shape
# Out:
# (128, 6)

# %%
df['condition'] = df['condition'].str.replace('0 users found this comment helpful.', 'Not Specified', regex=True)

# %%
df.loc[df['condition'] == 'Not Specified'].head(3)
# Out:
#                 drugName      condition  \
# 516       Nortrel 1 / 35  Not Specified
# 553       Loestrin 24 Fe  Not Specified
# 571  Ortho Tri-Cyclen Lo  Not Specified
#
#                                                 review  rating  usefulCount  \
# 516  "they switched necon nortrel saying andsameand...       2            0
# 553  "i loestrin 24 fe 6 months never problems emot...       7            0
# 571  "i love birth control spotting periods. little...       9            0
#
#      sentiment
# 516          0
# 553          1
# 571          1

# %%
# !pip install textblob
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: textblob in c:\users\91939\appdata\roaming\python\python312\site-packages (0.19.0)
# Requirement already satisfied: nltk>=3.9 in c:\users\91939\appdata\roaming\python\python312\site-packages (from textblob) (3.9.1)
# Requirement already satisfied: click in c:\users\91939\appdata\roaming\python\python312\site-packages (from nltk>=3.9->textblob) (8.1.8)
# Requirement already satisfied: joblib in c:\users\91939\appdata\roaming\python\python312\site-packages (from nltk>=3.9->textblob) (1.1.1)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\91939\appdata\roaming\python\python312\site-packages (from nltk>=3.9->textblob) (2024.11.6)
# Requirement already satisfied: tqdm in c:\users\91939\appdata\roaming\python\python312\site-packages (from nltk>=3.9->textblob) (4.67.1)
# Requirement already satisfied: colorama in c:\users\91939\appdata\roaming\python\python312\site-packages (from click->nltk>=3.9->textblob) (0.4.6)
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from nltk.stem import SnowballStemmer
from textblob import TextBlob

# %%
Snow_ball = SnowballStemmer("english")
df['review'] = df['review'].apply(lambda x: " ".join(Snow_ball.stem(word) for word in x.split()))

# %%
df.sample(3)
# Out:
#          drugName                    condition  \
# 108924      Paxil  generalized anxiety disorde
# 129969  Lidocaine                         pain
# 76846   Myrbetriq         urinary incontinence
#
#                                                    review  rating  \
# 108924  "mi anxieti sky rocket medic much doctor presc...       2
# 129969  "i start use 10 year ago pain foot torn tendon...      10
# 76846   "work immedi control bladder; however, upper r...       2
#
#         usefulCount  sentiment
# 108924           23          0
# 129969           24          1
# 76846            32          0

# %%
# to determine the polarity of the review
def sentiment(review):
    pol = []
    for i in review:
        analysis = TextBlob(i)
        pol.append(analysis.sentiment.polarity)
    return pol

# %%
df['review_sentiment'] = sentiment(df['review'])

# %%
df.sample(10)
# Out:
#                            drugName            condition  \
# 139542                   Topiramate   seizure prevention
# 28164                      Depakote             epilepsy
# 24504             Blisovi Fe 1 / 20        birth control
# 151076                  Phentermine          weight loss
# 39287                   Clindamycin  bacterial infection
# 15080                    Naltrexone    opiate dependence
# 89172                       Effexor           depression
# 108208  Acetaminophen / hydrocodone                 pain
# 17177                    Loratadine    allergic rhinitis
# 37536      Phentermine / topiramate          weight loss
#
#                                                    review  rating  \
# 139542  "i prescrib medicin treat petit mal seizures. ...       2
# 28164   "i noth good say drug, zero. reading, said dep...       1
# 24504   "this absolut worst. gildess fe 1/20 recal lov...       1
# 151076  "i phentermin 4 year off. 3 time total. first ...       2
# 39287   "i take 300 mg 2 tablets, 3 x day four day abs...       8
# 15080   "i recent went medic detox heroin 6 day vital ...       2
# 89172   "effexor help me, took week initi side effect ...       8
# 108208  "i broke half reliev pain effectively. advers ...       7
# 17177                 "slow get go last forev activated."      10
# 37536   "i 33 year old femal start take qysmia approx ...      10
#
#         usefulCount  sentiment  review_sentiment
# 139542           48          0          0.118750
# 28164            15          0          0.042857
# 24504             4          0         -0.381410
# 151076           33          0          0.125000
# 39287            36          1          0.065972
# 15080            28          0          0.037222
# 89172            30          1          0.007292
# 108208            2          1          0.216667
# 17177            20          1         -0.150000
# 37536            43          1         -0.022222

# %%
df.corr(numeric_only=True)
# Out:
#                     rating  usefulCount  sentiment  review_sentiment
# rating            1.000000     0.235121   0.916406          0.287993
# usefulCount       0.235121     1.000000   0.212763          0.073422
# sentiment         0.916406     0.212763   1.000000          0.261538
# review_sentiment  0.287993     0.073422   0.261538          1.000000

# %%
import nltk
nltk.download('punkt_tab')
from nltk import sent_tokenize
import gensim
from gensim.utils import simple_preprocess
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\91939\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
df['rev_tokens'] = df['review'].apply(simple_preprocess)
df['con_tokens'] = df['condition'].apply(simple_preprocess)

# %%
from gensim.models import Word2Vec

rev_sentences = df['rev_tokens'].tolist()
con_sentenses = df['con_tokens'].tolist()
corpus = rev_sentences + con_sentenses

w2v_model = Word2Vec(
    sentences=corpus,
    vector_size=100,
    window=5,
    min_count=2,
    workers=4
)

# %%
w2v_model.train(corpus,total_examples=w2v_model.corpus_count,epochs=w2v_model.epochs)
# Out:
# (42788158, 48073060)

# %%
def vectorize(text):
    tokens = text.split()
    vectors = [w2v_model.wv[word] for word in tokens if word in w2v_model.wv]
    if not vectors:
        return np.zeros(w2v_model.vector_size)
    return np.mean(vectors, axis=0)

# %%
df['condition_vector'] = df['condition'].apply(vectorize)

# %%
df['condition_vector'].iloc[0]
# Out:
# array([ 0.26202235,  0.09516133, -1.7913675 ,  1.1609713 ,  1.1995444 ,
#        -1.5318106 , -0.13857107,  0.5130634 ,  0.84636974, -0.5228144 ,
#         0.85615367, -0.88269645,  0.06347678,  0.42814016,  0.5891781 ,
#        -0.23661458,  0.5388462 ,  1.4257027 , -0.28665808, -0.5102076 ,
#        -0.17989881, -0.98445886, -0.48219612,  0.7103634 ,  0.4452869 ,
#         0.32237634, -0.545319  , -0.3495444 ,  0.46041194, -1.1782379 ,
#         1.9856186 , -0.7876396 , -0.03738825,  0.3014631 ,  1.4748453 ,
#         0.48161098, -0.7997138 , -0.18599331,  0.5583829 , -1.2849609 ,
#        -0.4575353 , -0.61091423, -0.24219616,  0.01951698, -1.2401942 ,
#         0.42791438,  0.67412204,  0.5293018 ,  0.30992076,  0.8789601 ,
#         0.33700487, -0.03998267, -0.29867083,  0.02876415, -0.7548315 ,
#         1.211142  , -0.09962711, -0.5492573 , -0.7137639 , -0.11729418,
#         0.76922655,  0.34296373,  1.7113794 , -0.09193554, -0.18627705,
#        -0.6379028 ,  0.71807796, -0.07715185,  0.59266126,  1.2575932 ,
#         0.9956277 ,  0.7157361 , -0.20699872,  1.0299188 ,  0.4982995 ,
#        -1.3498484 ,  1.6707987 ,  0.02409609, -0.21789704,  0.10311443,
#         0.23953693,  1.1548814 , -0.62823254, -0.7411296 , -0.7460804 ,
#         0.17620762, -0.7754962 ,  0.7985599 , -0.26429656,  0.07946964,
#         0.4842526 , -0.23022719, -1.0172293 ,  0.80336815, -0.52683276,
#         0.90724725,  1.4931598 , -0.28630626, -0.6821368 ,  1.0873985 ],
#       dtype=float32)

# %%
df['review_vector'] = df['review'].apply(vectorize)

# %%
df['review_vector'].iloc[0]
# Out:
# array([ 0.02043572, -0.29432553,  0.6599371 ,  0.60143334,  0.26456684,
#         0.15654469,  0.46531188,  0.36362973, -0.96188253, -1.2373585 ,
#         0.76947325, -0.4050742 ,  0.46366206,  0.51833993,  0.57152206,
#         1.053778  , -1.1247901 ,  0.48027492, -1.8074069 , -0.31240046,
#         0.99770397,  0.47000918,  1.6191505 , -0.7262144 ,  0.8973561 ,
#         1.5020599 ,  0.08589568, -0.85289764,  0.44220218, -0.42850545,
#         0.27739534,  0.08973486, -0.9751174 , -0.02152155, -0.14548437,
#        -0.07079919,  0.4301606 ,  0.6972127 ,  0.12947598, -0.00615398,
#         0.29257837, -0.55311567, -1.5330058 ,  0.4442177 ,  0.3492237 ,
#         0.23379578, -0.01515212,  0.17065531,  0.27178636,  0.13647383,
#        -0.19025521,  0.25747684,  0.17196552,  0.5694894 ,  1.6418399 ,
#         0.5031622 , -0.1318025 , -0.71771437, -0.4459981 , -0.21178728,
#        -0.22962874,  0.01509566,  0.44784495,  0.9268882 ,  0.326216  ,
#         1.056624  , -1.7731618 ,  0.79789144,  0.7239175 , -0.42226282,
#        -0.8332734 ,  0.61842066,  0.7062483 ,  0.8490136 ,  0.06297646,
#        -0.7462509 , -0.3600589 , -0.88407534,  1.4319795 , -0.4656277 ,
#         0.38456014,  0.12867902, -0.89281845, -0.7686953 ,  0.6011804 ,
#        -0.8805587 , -0.5248538 , -1.3999954 , -0.41147184,  0.5478391 ,
#        -0.82993644, -0.452389  ,  0.31458214,  0.3537871 , -0.2818787 ,
#         0.33900514, -0.86180425,  0.04213725,  0.560023  , -0.2930787 ],
#       dtype=float32)

# %%
df.sample()
# Out:
#       drugName                condition  \
# 20040   Plan B  emergency contraception
#
#                                                   review  rating  usefulCount  \
# 20040  "so unprotect sex week ago didnt pull forgot t...       8            9
#
#        sentiment  review_sentiment  \
# 20040          1           -0.2025
#
#                                               rev_tokens  \
# 20040  [so, unprotect, sex, week, ago, didnt, pull, f...
#
#                        con_tokens  \
# 20040  [emergency, contraception]
#
#                                         condition_vector  \
# 20040  [-0.38829604, 1.6878688, 1.2253608, 0.49942037...
#
#                                            review_vector
# 20040  [0.10614582, -0.5879552, 0.49083918, 0.6067515...

# %%
df.drop(columns=['rev_tokens','con_tokens'],inplace=True)

# %%
df.shape
# Out:
# (213869, 9)

# %%
grouped = df.groupby(['condition','drugName']).agg({
    'review_vector': lambda x: np.mean(np.vstack(x), axis=0),
    'condition_vector': 'first',
    'review_sentiment': ['mean', 'std'],
    'rating': ['mean', 'count'],
    'usefulCount': 'sum'
}).reset_index()

# %%
grouped.columns = [
    'condition',
    'drugName',
    'review_vector',
    'condition_vector',
    'mean_sentiment',
    'std_sentiment',
    'mean_rating',
    'review_count',
    'useful_sum'
]

# %%
X_review = np.vstack(grouped['review_vector'].values)
X_condition = np.vstack(grouped['condition_vector'].values)

X_numeric = grouped[['mean_sentiment',
                     'std_sentiment',
                     'mean_rating',
                     'review_count',
                     'useful_sum']].values

# %%
cond_dim = X_condition.shape[1]
rev_dim = X_review.shape[1]

cond_cols = [f'cond_emb_{i}' for i in range(cond_dim)]
rev_cols  = [f'rev_emb_{i}' for i in range(rev_dim)]

num_cols = [
    'mean_sentiment',
    'std_sentiment',
    'mean_rating',
    'review_count',
    'useful_sum'
]
columns = cond_cols + rev_cols + num_cols

# %%
X = np.hstack([X_condition, X_review, X_numeric])

# %%
X_df = pd.DataFrame(X, columns=columns)

# %%
X_df.isnull().sum()
# Out:
# cond_emb_0           0
# cond_emb_1           0
# cond_emb_2           0
# cond_emb_3           0
# cond_emb_4           0
#                   ...
# mean_sentiment       0
# std_sentiment     3415
# mean_rating          0
# review_count         0
# useful_sum           0
# Length: 205, dtype: int64

# %%
df = df.reset_index(drop=True)

# %%
X_df['drugName']=df['drugName']

# %%
Y_df = X_df['mean_sentiment']

# %%
X_df.drop(columns=['mean_sentiment'],inplace = True)

# %%
Y_df.shape
# Out:
# (9446,)

# %%
sns.kdeplot(Y_df)
# Out:
# <Axes: xlabel='mean_sentiment', ylabel='Density'>

# %%
Y_df = (grouped['mean_sentiment'] > 0).astype(int)

# %%
X_df.shape
# Out:
# (9446, 205)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
X_df['drugName'] = le.fit_transform(X_df['drugName'])

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, r2_score, classification_report

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X_df,Y_df,test_size=0.2,random_state=42)

# %%
rf = RandomForestClassifier(
    n_estimators=100,
    max_depth=15,
    n_jobs=-1,
    random_state=42
)

# %%
rf.fit(X_train,Y_train)
# Out:
# RandomForestClassifier(max_depth=15, n_jobs=-1, random_state=42)

# %%
pred = rf.predict(X_test)

# %%
accuracy_score(Y_test,pred)
# Out:
# 0.7984126984126985

# %%
from xgboost import XGBClassifier

model = XGBClassifier(
    objective='binary:logistic',
    eval_metric='logloss',
    tree_method='hist'
)

model.fit(X_train, Y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
xg_pred = model.predict(X_test)

# %%
accuracy_score(Y_test,xg_pred)
# Out:
# 0.8063492063492064

# %%
Y_train.value_counts(normalize=True)
# Out:
# mean_sentiment
# 1    0.724325
# 0    0.275675
# Name: proportion, dtype: float64

# %%
from sklearn.metrics import classification_report, confusion_matrix

print(confusion_matrix(Y_test, xg_pred))
print(classification_report(Y_test, xg_pred))
# Out:
# [[ 251  273]
#  [  93 1273]]
#               precision    recall  f1-score   support
#
#            0       0.73      0.48      0.58       524
#            1       0.82      0.93      0.87      1366
#
#     accuracy                           0.81      1890
#    macro avg       0.78      0.71      0.73      1890
# weighted avg       0.80      0.81      0.79      1890

# %%
y_prob = model.predict_proba(X_test)[:, 1]
xg_pred = (y_prob > 0.6).astype(int)
