# %% [markdown]
# ## Data Aggrigation

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_train = pd.read_csv('drugsComTrain_raw.csv')
df_test = pd.read_csv('drugsComTest_raw.csv')

# %%
data = pd.concat([df_train,df_test])

# %%
data.sample(30)
# Out:
#         uniqueID                               drugName  \
# 30316     129068                         Levonorgestrel
# 127033    108551                 Bupropion / naltrexone
# 34652     215701                                 Copper
# 32598     146889                             Alprazolam
# 16641     184726                          Canagliflozin
# 153243     13045                                Dapsone
# 55583       6516  Sodium biphosphate / sodium phosphate
# 51271     212517                                 Lysine
# 80481      66154                            Propranolol
# 161179    224499                          Levothyroxine
# 28893      86719                                Triavil
# 97003      94797                                Abilify
# 131704      9904                         Lo Loestrin Fe
# 8153      160957                            Risperidone
# 19142     154905                          Metronidazole
# 151138    192003       Drospirenone / ethinyl estradiol
# 107799    179174                             Olanzapine
# 1829        2770                                Mydayis
# 10912      16687                                    Yaz
# 8836       83103                                  Paxil
# 40315     137521                           Isotretinoin
# 100240    146895                             Alprazolam
# 144647    179463                             Olanzapine
# 95883     111568                                  Cipro
# 45758     178710                                Victoza
# 41718      83965       Ethinyl estradiol / norgestimate
# 17960     120130                            Montelukast
# 32077     104855     Ethinyl estradiol / levonorgestrel
# 144940    109243                              Nexplanon
# 77069     168645                             Vilazodone
#
#                        condition  \
# 30316    Emergency Contraception
# 127033                   Obesity
# 34652              Birth Control
# 32598                 Depression
# 16641           Diabetes, Type 2
# 153243        Linear IgA Disease
# 55583               Constipation
# 51271             Herpes Simplex
# 80481        Migraine Prevention
# 161179       Hashimoto's disease
# 28893                    Anxiety
# 97003                 Depression
# 131704             Birth Control
# 8153               Schizophrenia
# 19142        Bacterial Infection
# 151138             Birth Control
# 107799                  Insomnia
# 1829                        ADHD
# 10912              Birth Control
# 8836                  Depression
# 40315                       Acne
# 100240                   Anxiety
# 144647           Bipolar Disorde
# 95883    Urinary Tract Infection
# 45758           Diabetes, Type 2
# 41718              Birth Control
# 17960                     Asthma
# 32077              Birth Control
# 144940             Birth Control
# 77069   Major Depressive Disorde
#
#                                                    review  rating       date  \
# 30316   "Hi ladies im here to share my experience wuth...       8  10-Nov-15
# 127033  "I&#039;ve been on Contrave for almost 2 weeks...       4  24-Dec-14
# 34652   "I&#039;m 25 with two kids. I had my insertion...       1  24-Mar-17
# 32598   "I agree with everything that has already been...      10  10-Mar-16
# 16641   "Started taking Invokana a little over a year ...       8  20-Apr-16
# 153243  "I have been taking dapsone since December 200...      10   4-Apr-12
# 55583   "So good that I went on the internet and wrote...      10  14-Oct-17
# 51271   "I hsve HSV1  on geitals from oral sex. I was ...      10  12-Apr-16
# 80481   "This medicine has helped my migraines signifi...       9  31-Dec-09
# 161179  "I started on Tirosint when they stopped makin...      10  10-Nov-14
# 28893   "When I was in my early 20s I was having a gre...       9  30-Oct-11
# 97003   "Abilify worked for me within 1 1/2 weeks, yes...      10  15-Apr-14
# 131704  "I&#039;m a week from completing my 2nd pack o...       9   5-Sep-14
# 8153    "This was the first AAP I was on.  It worked r...       6   8-Aug-16
# 19142   "I have to say this time around from the ER to...       7   5-Dec-16
# 151138  "I switched off my old birth control because i...       1  21-Nov-16
# 107799  "Started Zyprexa 5mg for a week, bumped up to ...      10  14-Nov-16
# 1829    "I was prescribed 50 mg. 1st day I could liter...       1  12-Sep-17
# 10912   "This pill was horrible! I got cysts and had t...       1   2-Dec-09
# 8836    "I&#039;ve used Paxil when I was in my 20&#039...       8   2-Feb-14
# 40315   "It&#039;s been about 9 months since I stopped...       7   7-Jul-09
# 100240  "Way too addictive. Very expensive in my count...       6   1-Mar-16
# 144647  "I&#039;ve been taking this for about week and...       7  30-Aug-09
# 95883   "I was prescribed this medication for twice a ...       1  16-Aug-17
# 45758   "I&#039;ve been on it for 3 months.  I started...       4  12-Apr-16
# 41718   "I&#039;ve been on Trinessa for about 5 or 6 m...       4  10-Jul-17
# 17960   "I have been using this medication for 18 year...      10  26-Jul-17
# 32077   "My only complaint is that my period has NOT e...       5  16-Mar-10
# 144940  "I got the implant August of 2015 right before...       6  20-Feb-17
# 77069   "This drug was miraculous!. It was as if I was...      10  16-Feb-17
#
#         usefulCount
# 30316            14
# 127033           21
# 34652             3
# 32598            74
# 16641            25
# 153243            9
# 55583             1
# 51271            10
# 80481            71
# 161179           63
# 28893            52
# 97003            61
# 131704           13
# 8153              8
# 19142             6
# 151138            1
# 107799           13
# 1829             10
# 10912             7
# 8836             49
# 40315            16
# 100240           18
# 144647           16
# 95883            15
# 45758            41
# 41718             5
# 17960             8
# 32077            27
# 144940            0
# 77069            25

# %%
df = data.copy()

# %%
df.sample(10)
# Out:
#         uniqueID                                           drugName  \
# 126252    105708                                 Methylprednisolone
# 85144     203382                                       Indomethacin
# 29272      11245  Drospirenone / ethinyl estradiol / levomefolat...
# 23916      41700                                          Clonidine
# 12757      81071                                          Hypercare
# 19854      86491                                           Invokana
# 46462     147170                                         Alprazolam
# 22023      41289                          Acetaminophen / oxycodone
# 158055     17434                   Ethinyl estradiol / etonogestrel
# 149126    139445                                        Armodafinil
#
#                 condition                                             review  \
# 126252     Osteoarthritis  "The medication was a wonder drug and I was ab...
# 85144         Gout, Acute  "Have had several bouts of gout and the pain i...
# 29272                Acne  "I was originally on Yaz, cleared up skin in 3...
# 23916   Opiate Withdrawal  "I was hooked on pain meds after a surgery. It...
# 12757       Hyperhidrosis  "I&#039;ve read pages of these reviews after a...
# 19854    Diabetes, Type 2  "Invokana 100 mg daily  in addition to Metform...
# 46462       Panic Disorde  "I have panic disorder when I&#039;m under str...
# 22023        Chronic Pain  "I use it for back pain...it works okay for th...
# 158055      Birth Control  "Honestly, it is a pretty effective birth cont...
# 149126         Depression  "My psychiatrist initially prescribed Nuvigil ...
#
#         rating       date  usefulCount
# 126252       9   4-Sep-09           28
# 85144        9  19-Oct-15           23
# 29272        7   5-Dec-11            4
# 23916       10   9-Nov-15           63
# 12757       10  22-Feb-12            1
# 19854       10  14-Dec-16           12
# 46462        9   9-Aug-13           82
# 22023        7  19-Jan-13           23
# 158055       4   7-Mar-17            5
# 149126      10  26-Aug-11           20

# %% [markdown]
# From initial observation, I can say that condition and review column consists of invalid char so it need to be cleaned

# %% [markdown]
# ## Basic anaysis

# %%
df.shape
# Out:
# (215063, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 215063 entries, 0 to 53765
# Data columns (total 7 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   uniqueID     215063 non-null  int64
#  1   drugName     215063 non-null  object
#  2   condition    213869 non-null  object
#  3   review       215063 non-null  object
#  4   rating       215063 non-null  int64
#  5   date         215063 non-null  object
#  6   usefulCount  215063 non-null  int64
# dtypes: int64(3), object(4)
# memory usage: 13.1+ MB

# %% [markdown]
# Data column is in string format. It need to be converted into date format

# %%
df.describe()
# Out:
#             uniqueID         rating    usefulCount
# count  215063.000000  215063.000000  215063.000000
# mean   116039.364814       6.990008      28.001004
# std     67007.913366       3.275554      36.346069
# min         0.000000       1.000000       0.000000
# 25%     58115.500000       5.000000       6.000000
# 50%    115867.000000       8.000000      16.000000
# 75%    173963.500000      10.000000      36.000000
# max    232291.000000      10.000000    1291.000000

# %%
df.isnull().sum()
# Out:
# uniqueID          0
# drugName          0
# condition      1194
# review            0
# rating            0
# date              0
# usefulCount       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# There are 1194 rows are null values in condition column

# %%
df.corr(numeric_only=True)
# Out:
#              uniqueID    rating  usefulCount
# uniqueID     1.000000  0.016336     0.017567
# rating       0.016336  1.000000     0.234860
# usefulCount  0.017567  0.234860     1.000000

# %% [markdown]
# ## Univariate analysis

# %%
from wordcloud import WordCloud, STOPWORDS

# %%
wordcloud = WordCloud(stopwords=set(STOPWORDS),
                      background_color='rgb(73, 252, 243)',
                      height=800,
                      width=1000
).generate(str(df['drugName']))


plt.figure(figsize=(10,10))
plt.title('Word Cloud (Drug Names)', fontsize = 10)
plt.axis("off")
plt.imshow(wordcloud)

# %% [markdown]
# The above cloud includes the metadata as well like dtype, Length etc. Because the str(pd.Series) includes meta data as well

# %%
wordcloud = WordCloud(stopwords=set(STOPWORDS),
                      background_color='rgb(73, 252, 243)',
                      height=800,
                      width=1000
).generate(str(df['condition']))


plt.figure(figsize=(10,10))
plt.title('Word Cloud (condition)', fontsize = 10)
plt.axis("off")
plt.imshow(wordcloud)

# %% [markdown]
# Most of the times, we can see the birth control, ADHD, Ventricular etc

# %%
df['rating'].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
sns.kdeplot(df['rating'])
# Out:
# <Axes: xlabel='rating', ylabel='Density'>

# %% [markdown]
# Most of the ratings are higher ratings ie 10, 9, 8. Some drugs about 13% also got worst rating 1

# %%
print((df['rating'] > 5).sum())
print((df['rating'] <= 5).sum())
# Out:
# 150768
# 64295

# %% [markdown]
# Data is imbalance by a huge difference. May be the data includes so much of positive drugs. Hence the model may not perform well on negative drugs so well

# %% [markdown]
# ## Bivariante analysis

# %%
top_drugs_10 = df[df['rating'] == 10]['drugName'].value_counts().head(20)
bar=sns.barplot(top_drugs_10)
bar.set_title('Top 20 drugs whose having 10 rating')
bar.set_xticklabels(bar.get_xticklabels(), rotation=90, ha='right')
sns.set(style = 'darkgrid', font_scale = 1.3)
plt.rcParams['figure.figsize'] = [17, 5]
# Out:
# C:\Users\91939\AppData\Local\Temp\ipykernel_18776\3663489246.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   bar.set_xticklabels(bar.get_xticklabels(), rotation=90, ha='right')

# %%
top_drugs_1 = df[df['rating'] == 1]['drugName'].value_counts().head(20)
bar=sns.barplot(top_drugs_1)
bar.set_title('Top 20 drugs whose having 1 rating')
bar.set_xticklabels(bar.get_xticklabels(), rotation=90, ha='right')
sns.set(style = 'darkgrid', font_scale = 1.3)
plt.rcParams['figure.figsize'] = [8, 8]
# Out:
# C:\Users\91939\AppData\Local\Temp\ipykernel_18776\1902578690.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   bar.set_xticklabels(bar.get_xticklabels(), rotation=90, ha='right')

# %%
top_conditions = df['condition'].value_counts().head(20)
bar=sns.barplot(top_conditions)
bar.set_title('Top conditions')
bar.set_xticklabels(bar.get_xticklabels(), rotation=90, ha='right')
sns.set(style = 'darkgrid', font_scale = 1.3)
plt.rcParams['figure.figsize'] = [5, 5]
# Out:
# C:\Users\91939\AppData\Local\Temp\ipykernel_18776\4106974381.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   bar.set_xticklabels(bar.get_xticklabels(), rotation=90, ha='right')

# %% [markdown]
# ### visualizing as per date

# %%
df['date'] = pd.to_datetime(df['date'])
# Out:
# C:\Users\91939\AppData\Local\Temp\ipykernel_18776\3532345252.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['date'] = pd.to_datetime(df['date'])

# %%
df['year']=df['date'].dt.year
df['month']=df['date'].dt.month
df['day']=df['date'].dt.day

# %%
df.head(2)
# Out:
#    uniqueID    drugName                     condition  \
# 0    206461   Valsartan  Left Ventricular Dysfunction
# 1     95260  Guanfacine                          ADHD
#
#                                               review  rating       date  \
# 0  "It has no side effect, I take it in combinati...       9 2012-05-20
# 1  "My son is halfway through his fourth week of ...       8 2010-04-27
#
#    usefulCount  year  month  day
# 0           27  2012      5   20
# 1          192  2010      4   27

# %%
rating=df.groupby('year')['rating'].mean()
rating.plot(kind='bar',figsize=(10,5),color='green')
plt.title('Mean rating in a year')
# Out:
# Text(0.5, 1.0, 'Mean rating in a year')

# %%
rating=df.groupby('month')['rating'].mean()
rating.plot(kind='bar',figsize=(10,5),color='green')
plt.title('Mean rating in a month')
# Out:
# Text(0.5, 1.0, 'Mean rating in a month')

# %%
rating=df.groupby('day')['rating'].mean()
rating.plot(kind='bar',figsize=(10,5),color='green')
plt.title('Mean rating in a day')
# Out:
# Text(0.5, 1.0, 'Mean rating in a day')

# %% [markdown]
# As we seen the data is distributed equally across the year, month and day. So no need of date column

# %% [markdown]
# ### Usefull count visualization

# %%
df["usefulCount"].describe()
# Out:
# count    215063.000000
# mean         28.001004
# std          36.346069
# min           0.000000
# 25%           6.000000
# 50%          16.000000
# 75%          36.000000
# max        1291.000000
# Name: usefulCount, dtype: float64

# %% [markdown]
# As we see the stdev is so high and the data distribution is so large. So normalizing it will helpfull

# %%
df['usefulCount'].nunique()
# Out:
# 397

# %%
plt.figure(figsize=(14,6))
sns.distplot(df["usefulCount"],color="green")
plt.xticks(rotation='vertical')
plt.xlabel('', fontsize=12)
plt.ylabel('', fontsize=12)
plt.title("Distribution of usefulCount")
# Out:
# C:\Users\91939\AppData\Local\Temp\ipykernel_18776\2665249276.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["usefulCount"],color="green")
# Text(0.5, 1.0, 'Distribution of usefulCount')

# %% [markdown]
# ## Text preprocessing

# %% [markdown]
# #### Droping null values

# %%
df=df.dropna(how="any", axis=0)

# %%
import re
def process(text):
    cleaned_text = re.sub(re.compile('<.*?>'), '', text) #removes html tags
    cleaned_text = cleaned_text.lower() #lowers the data
    cleaned_text = cleaned_text.replace(r'[^\w\d\s]',' ') #removes the special characters
    cleaned_text = cleaned_text.replace(r'[^\x00-\x7F]+',' ') # remove all non aschi values
    cleaned_text = cleaned_text.strip() #removes trailing and leading spaces
    cleaned_text = cleaned_text.replace(r'\s+',' ') # replace multiple spaces with single one
    cleaned_text = cleaned_text.replace(r'\.{2,}', ' ') # replace multiple . with single
    cleaned_text = cleaned_text.replace("&#039;", "") #remove repeating pattern
    
    return cleaned_text

# %% [markdown]
# ### condition series preprocessing

# %%
df['condition'] = df['condition'].apply(process)

# %%
df['review'] = df['review'].apply(process)

# %%
df.sample(20)
# Out:
#         uniqueID                           drugName                condition  \
# 32831      72765  Ethinyl estradiol / norethindrone            birth control
# 74877      44623                             Asacol      lymphocytic colitis
# 21551     171043                         Quetiapine          bipolar disorde
# 38406      81431                                Yaz            birth control
# 62155     160700                          Buspirone                  anxiety
# 18881     162749                           Cefdinir             otitis media
# 149364    190160                           Phenytek                 seizures
# 49772     188229                           ParaGard            birth control
# 136812    168957                         Vilazodone               depression
# 16674     200163                        Varenicline        smoking cessation
# 51570     200623                        Varenicline        smoking cessation
# 86024      17019         Phillips' Milk of Magnesia             constipation
# 122554    187498    Monistat 3-Day Combination Pack  vaginal yeast infection
# 14044       4671                             Belviq              weight loss
# 36353     165004           Phentermine / topiramate              weight loss
# 11237     120907                        Venlafaxine               depression
# 125633    214378                        Tioconazole  vaginal yeast infection
# 16499     207650              Suprep Bowel Prep Kit        bowel preparation
# 76407      66342                       Valacyclovir               cold sores
# 67835     133869                         Bactrim DS  urinary tract infection
#
#                                                    review  rating       date  \
# 32831   "i love it! i had irregular periods that laste...      10 2015-08-22
# 74877   "i am newly diagnosed with lc, i am 38 years o...       8 2011-02-04
# 21551   "my son has recently been taking just seroguel...       8 2008-03-27
# 38406   "i took yaz for 4 years and loved it up until ...       6 2011-08-09
# 62155   "ive had a great experience with buspar 20 mg ...      10 2012-08-24
# 18881   "my 11 year old son got put on this drug for e...       1 2017-01-17
# 149364  "i had my first ever seizure on 8/4/93; one da...      10 2015-02-23
# 49772   "2 years with the paragard iud.\r\nside effect...       2 2017-10-05
# 136812  "female, age 55. chronic dysthymia with episod...       5 2012-09-25
# 16674   "i smoked for 50+ years.  took it for one week...      10 2015-02-14
# 51570   "smoked for 35 years, quit for a year once and...      10 2009-05-31
# 86024   "about a week after i got my wisdom teeth surg...       8 2015-06-11
# 122554  "im 15 &amp; i had my first yi about a month a...       5 2015-07-08
# 14044   "i see a lot of negative experiences on here. ...      10 2015-06-25
# 36353   "in 5 months, i gained 25lb. and my weight los...       1 2015-08-11
# 11237   "after completely stopping my antidepressant a...       8 2017-12-09
# 125633  "inserted the medication within two hours was ...       1 2015-10-11
# 16499   "i read a review that said this stuff was &quo...       8 2016-05-26
# 76407   "had one of those tricky cold sores where ther...      10 2014-12-29
# 67835   "works really well, but i also had some side e...      10 2008-11-04
#
#         usefulCount  year  month  day
# 32831             4  2015      8   22
# 74877            23  2011      2    4
# 21551            62  2008      3   27
# 38406             2  2011      8    9
# 62155            87  2012      8   24
# 18881             8  2017      1   17
# 149364            8  2015      2   23
# 49772             4  2017     10    5
# 136812           10  2012      9   25
# 16674            26  2015      2   14
# 51570            26  2009      5   31
# 86024            38  2015      6   11
# 122554            7  2015      7    8
# 14044            79  2015      6   25
# 36353             7  2015      8   11
# 11237             0  2017     12    9
# 125633            5  2015     10   11
# 16499            18  2016      5   26
# 76407            28  2014     12   29
# 67835             8  2008     11    4

# %% [markdown]
# After doing the preprocessing, in some reviews we find \r, \n and emojis and @amp for and . So remove them also

# %%
emoji_pattern = re.compile(
    "["
    u"\U0001F600-\U0001F64F"
    u"\U0001F300-\U0001F5FF"
    u"\U0001F680-\U0001F6FF"
    u"\U0001F1E0-\U0001F1FF"
    "]+",
    flags=re.UNICODE,
)

# %%
df['review'] = (df['review'].str.replace(r'[\n\r]+', ' ', regex=True).str.replace(emoji_pattern, '', regex=True))

# %%
df['review'] = df['review'].str.replace('&amp;', 'and', regex=True)

# %%
df.sample(20)
# Out:
#         uniqueID                                           drugName  \
# 77184      75075                                     Nitrofurantoin
# 64622     229581                                         Lurasidone
# 14413      76953                                         Lorcaserin
# 47493     217749                                          Strattera
# 29432      32336                                         Lisinopril
# 18318     175674                                           Levaquin
# 109187    174756                                             Dulera
# 147048    147481                                         Alprazolam
# 138911     63236  Citric acid / magnesium oxide / sodium picosul...
# 9580       18252                   Ethinyl estradiol / etonogestrel
# 129573    211407            Fluocinolone / hydroquinone / tretinoin
# 57514     220909                                     Loestrin 24 Fe
# 39027     177325                                         Duloxetine
# 141528    172206                                         Clonazepam
# 53647     152258                                      Ciprofloxacin
# 135322    228065                                       Etonogestrel
# 76475     221354                                   Dextromethorphan
# 19892     228001                                       Etonogestrel
# 31454     185703                                            Saxenda
# 74532     173918                                           Provigil
#
#                             condition  \
# 77184               bladder infection
# 64622                 bipolar disorde
# 14413                         obesity
# 47493                            adhd
# 29432             high blood pressure
# 18318                       sinusitis
# 109187            asthma, maintenance
# 147048                  panic disorde
# 138911              bowel preparation
# 9580                    birth control
# 129573                        melasma
# 57514       polycystic ovary syndrome
# 39027                      depression
# 141528                        anxiety
# 53647   skin or soft tissue infection
# 135322                  birth control
# 76475                           cough
# 19892                   birth control
# 31454                         obesity
# 74532                      depression
#
#                                                    review  rating       date  \
# 77184              "macrobid caused me to have diarrhea."       1 2009-03-01
# 64622   "diagnosed 20  years ago with bipolar 1.  stru...       8 2014-12-28
# 14413   "just started on  belviq a week ago and im  so...      10 2015-05-19
# 47493   "hey, im a 20 y/o medical assistant (internal ...       4 2016-03-21
# 29432   "i started 10 mg once a day 2 weeks ago for hb...       2 2016-05-12
# 18318   "do not use this drug!!! i was prescribed lava...       1 2017-06-22
# 109187  "i was just prescribed dulera today and notice...       2 2013-04-29
# 147048  "i have been on xanax (alprazolam) for over 10...      10 2009-10-08
# 138911  "1pm procedure tuesday, so clear liquid fast m...      10 2016-03-22
# 9580    "i been on nuva ring for 2 months. i love the ...       8 2009-04-06
# 129573  "had  so much dark spots and my doctor prescri...      10 2016-11-01
# 57514   "i started the pill after being diagnosed with...       9 2009-07-13
# 39027   "this is like a miracle drug to me. i suffer f...       9 2016-12-06
# 141528  "i suffer from health anxiety. every new mole,...      10 2017-10-31
# 53647   "had feeling in my lower abdomen and scrotal/t...       8 2015-11-06
# 135322  "i had the implanon inserted on the 20/12/2010...       8 2011-03-31
# 76475   "im currently sitting on the toilet because i ...       1 2016-05-12
# 19892   "ive had implanon since november 2009 and at f...       8 2010-10-16
# 31454   "started saxenda nearly 3 weeks ago.no change ...       1 2016-07-01
# 74532   "this is a wonder drug in the use of depressio...      10 2009-05-20
#
#         usefulCount  year  month  day
# 77184             9  2009      3    1
# 64622            73  2014     12   28
# 14413            21  2015      5   19
# 47493            18  2016      3   21
# 29432            25  2016      5   12
# 18318            14  2017      6   22
# 109187           29  2013      4   29
# 147048           20  2009     10    8
# 138911            6  2016      3   22
# 9580              6  2009      4    6
# 129573           28  2016     11    1
# 57514            38  2009      7   13
# 39027            43  2016     12    6
# 141528            0  2017     10   31
# 53647             6  2015     11    6
# 135322            0  2011      3   31
# 76475             7  2016      5   12
# 19892             1  2010     10   16
# 31454            17  2016      7    1
# 74532           287  2009      5   20

# %% [markdown]
# Now the review and conditions looks good

# %% [markdown]
# ## Feature transformation
