# %% [markdown]
# ## Data Aggrigation

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_train = pd.read_csv('drugsComTrain_raw.csv')
df_test = pd.read_csv('drugsComTest_raw.csv')

# %%
data = pd.concat([df_train,df_test])

# %%
data.sample(5)
# Out:
#         uniqueID                      drugName                condition  \
# 56924      75665                L-methylfolate               Depression
# 102081    131138                       Kenalog                Psoriasis
# 127945     68017                        Plan B  Emergency Contraception
# 10694     180040  Adapalene / benzoyl peroxide                     Acne
# 36950     105502                 Triamcinolone        Atopic Dermatitis
#
#                                                    review  rating       date  \
# 56924   "I have suffered from depression for about 30 ...       9  24-Feb-12
# 102081                  "Only thing that helped my scalp"       9  26-Mar-13
# 127945  "Hey ladies!! Just like you I was reading thes...      10   2-Feb-16
# 10694   "I started using Epiduo in June and since then...       9  16-Aug-13
# 36950   "The triamcinolone ointment was prescribed bec...      10  30-Aug-09
#
#         usefulCount
# 56924            45
# 102081           19
# ...

# %%
df = data.copy()

# %%
df.sample(10)
# Out:
#         uniqueID                             drugName  \
# 48906     164873             Phentermine / topiramate
# 86830     124662  Chlorpheniramine / dextromethorphan
# 103078    202086       Benzoyl peroxide / clindamycin
# 3122      187423      Monistat 3-Day Combination Pack
# 98846     209136                             Skelaxin
# 46885     188173                           Xtampza ER
# 111477    207681                Suprep Bowel Prep Kit
# 17134     100619      Desogestrel / ethinyl estradiol
# 83383     206953                            Seasonale
# 95948      80896                               Delsym
#
#                          condition  \
# 48906                  Weight Loss
# 86830   Cough and Nasal Congestion
# 103078                        Acne
# 3122       Vaginal Yeast Infection
# 98846                 Muscle Spasm
# 46885                 Chronic Pain
# 111477           Bowel Preparation
# 17134                Birth Control
# 83383                Birth Control
# ...

# %% [markdown]
# From initial observation, I can say that condition and review column consists of invalid char so it need to be cleaned

# %% [markdown]
# ## Basic anaysis

# %%
df.shape
# Out:
# (215063, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 215063 entries, 0 to 53765
# Data columns (total 7 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   uniqueID     215063 non-null  int64
#  1   drugName     215063 non-null  object
#  2   condition    213869 non-null  object
#  3   review       215063 non-null  object
#  4   rating       215063 non-null  int64
#  5   date         215063 non-null  object
#  6   usefulCount  215063 non-null  int64
# dtypes: int64(3), object(4)
# memory usage: 13.1+ MB

# %% [markdown]
# Data column is in string format. It need to be converted into date format

# %%
df.describe()
# Out:
#             uniqueID         rating    usefulCount
# count  215063.000000  215063.000000  215063.000000
# mean   116039.364814       6.990008      28.001004
# std     67007.913366       3.275554      36.346069
# min         0.000000       1.000000       0.000000
# 25%     58115.500000       5.000000       6.000000
# 50%    115867.000000       8.000000      16.000000
# 75%    173963.500000      10.000000      36.000000
# max    232291.000000      10.000000    1291.000000

# %%
df.isnull().sum()
# Out:
# uniqueID          0
# drugName          0
# condition      1194
# review            0
# rating            0
# date              0
# usefulCount       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# There are 1194 rows are null values in condition column

# %%
df.corr(numeric_only=True)
# Out:
#              uniqueID    rating  usefulCount
# uniqueID     1.000000  0.016336     0.017567
# rating       0.016336  1.000000     0.234860
# usefulCount  0.017567  0.234860     1.000000

# %% [markdown]
# ## Univariate analysis

# %%
from wordcloud import WordCloud, STOPWORDS

# %%
wordcloud = WordCloud(stopwords=set(STOPWORDS),
                      background_color='rgb(73, 252, 243)',
                      height=800,
                      width=1000
).generate(str(df['drugName']))


plt.figure(figsize=(10,10))
plt.title('Word Cloud (Drug Names)', fontsize = 10)
plt.axis("off")
plt.imshow(wordcloud)

# %% [markdown]
# The above cloud includes the metadata as well like dtype, Length etc. Because the str(pd.Series) includes meta data as well

# %%
wordcloud = WordCloud(stopwords=set(STOPWORDS),
                      background_color='rgb(73, 252, 243)',
                      height=800,
                      width=1000
).generate(str(df['condition']))


plt.figure(figsize=(10,10))
plt.title('Word Cloud (condition)', fontsize = 10)
plt.axis("off")
plt.imshow(wordcloud)

# %% [markdown]
# Most of the times, we can see the birth control, ADHD, Ventricular etc

# %%
df['rating'].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
sns.kdeplot(df['rating'])
# Out:
# <Axes: xlabel='rating', ylabel='Density'>

# %% [markdown]
# Most of the ratings are higher ratings ie 10, 9, 8. Some drugs about 13% also got worst rating 1

# %%
print((df['rating'] > 5).sum())
print((df['rating'] <= 5).sum())
# Out:
# 150768
# 64295

# %% [markdown]
# Data is imbalance by a huge difference. May be the data includes so much of positive drugs. Hence the model may not perform well on negative drugs so well

# %% [markdown]
# ## Bivariante analysis

# %%
top_drugs_10 = df[df['rating'] == 10]['drugName'].value_counts().head(20)
bar=sns.barplot(top_drugs_10)
bar.set_title('Top 20 drugs whose having 10 rating')
bar.set_xticklabels(bar.get_xticklabels(), rotation=90, ha='right')
sns.set(style = 'darkgrid', font_scale = 1.3)
plt.rcParams['figure.figsize'] = [17, 5]
# Out:
# C:\Users\91939\AppData\Local\Temp\ipykernel_15880\3663489246.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   bar.set_xticklabels(bar.get_xticklabels(), rotation=90, ha='right')

# %%
top_drugs_1 = df[df['rating'] == 1]['drugName'].value_counts().head(20)
bar=sns.barplot(top_drugs_1)
bar.set_title('Top 20 drugs whose having 1 rating')
bar.set_xticklabels(bar.get_xticklabels(), rotation=90, ha='right')
sns.set(style = 'darkgrid', font_scale = 1.3)
plt.rcParams['figure.figsize'] = [8, 8]
# Out:
# C:\Users\91939\AppData\Local\Temp\ipykernel_15880\1902578690.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   bar.set_xticklabels(bar.get_xticklabels(), rotation=90, ha='right')

# %%
top_conditions = df['condition'].value_counts().head(20)
bar=sns.barplot(top_conditions)
bar.set_title('Top conditions')
bar.set_xticklabels(bar.get_xticklabels(), rotation=90, ha='right')
sns.set(style = 'darkgrid', font_scale = 1.3)
plt.rcParams['figure.figsize'] = [5, 5]
# Out:
# C:\Users\91939\AppData\Local\Temp\ipykernel_15880\4106974381.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   bar.set_xticklabels(bar.get_xticklabels(), rotation=90, ha='right')

# %% [markdown]
# ### visualizing as per date

# %%
df['date'] = pd.to_datetime(df['date'])
# Out:
# C:\Users\91939\AppData\Local\Temp\ipykernel_15880\3532345252.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['date'] = pd.to_datetime(df['date'])

# %%
df['year']=df['date'].dt.year
df['month']=df['date'].dt.month
df['day']=df['date'].dt.day

# %%
df.head(2)
# Out:
#    uniqueID    drugName                     condition  \
# 0    206461   Valsartan  Left Ventricular Dysfunction
# 1     95260  Guanfacine                          ADHD
#
#                                               review  rating       date  \
# 0  "It has no side effect, I take it in combinati...       9 2012-05-20
# 1  "My son is halfway through his fourth week of ...       8 2010-04-27
#
#    usefulCount  year  month  day
# 0           27  2012      5   20
# 1          192  2010      4   27

# %%
rating=df.groupby('year')['rating'].mean()
rating.plot(kind='bar',figsize=(10,5),color='green')
plt.title('Mean rating in a year')
# Out:
# Text(0.5, 1.0, 'Mean rating in a year')

# %%
rating=df.groupby('month')['rating'].mean()
rating.plot(kind='bar',figsize=(10,5),color='green')
plt.title('Mean rating in a month')
# Out:
# Text(0.5, 1.0, 'Mean rating in a month')

# %%
rating=df.groupby('day')['rating'].mean()
rating.plot(kind='bar',figsize=(10,5),color='green')
plt.title('Mean rating in a day')
# Out:
# Text(0.5, 1.0, 'Mean rating in a day')

# %% [markdown]
# As we seen the data is distributed equally across the year, month and day. So no need of date column

# %% [markdown]
# ### Usefull count visualization

# %%
df["usefulCount"].describe()
# Out:
# count    215063.000000
# mean         28.001004
# std          36.346069
# min           0.000000
# 25%           6.000000
# 50%          16.000000
# 75%          36.000000
# max        1291.000000
# Name: usefulCount, dtype: float64

# %% [markdown]
# As we see the stdev is so high and the data distribution is so large. So normalizing it will helpfull

# %%
df['usefulCount'].nunique()
# Out:
# 397

# %%
plt.figure(figsize=(14,6))
sns.distplot(df["usefulCount"],color="green")
plt.xticks(rotation='vertical')
plt.xlabel('', fontsize=12)
plt.ylabel('', fontsize=12)
plt.title("Distribution of usefulCount")
# Out:
# C:\Users\91939\AppData\Local\Temp\ipykernel_15880\2665249276.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["usefulCount"],color="green")
# Text(0.5, 1.0, 'Distribution of usefulCount')

# %% [markdown]
# ## Text preprocessing

# %% [markdown]
# #### Droping null values

# %%
df=df.dropna(how="any", axis=0)

# %%
import re
def process(text):
    cleaned_text = re.sub(re.compile('<.*?>'), '', text) #removes html tags
    cleaned_text = cleaned_text.lower() #lowers the data
    cleaned_text = cleaned_text.replace(r'[^\w\d\s]',' ') #removes the special characters
    cleaned_text = cleaned_text.replace(r'[^\x00-\x7F]+',' ') # remove all non aschi values
    cleaned_text = cleaned_text.strip() #removes trailing and leading spaces
    cleaned_text = cleaned_text.replace(r'\s+',' ') # replace multiple spaces with single one
    cleaned_text = cleaned_text.replace(r'\.{2,}', ' ') # replace multiple . with single
    cleaned_text = cleaned_text.replace("&#039;", "") #remove repeating pattern
    
    return cleaned_text

# %% [markdown]
# ### condition series preprocessing

# %%
df['condition'] = df['condition'].apply(process)

# %%
df['review'] = df['review'].apply(process)

# %%
df.sample(20)
# Out:
#         uniqueID                  drugName                    condition  \
# 10469     213197                Ticagrelor      acute coronary syndrome
# 88296     220969                    Menest      postmenopausal symptoms
# 41499     146629                Tamsulosin         urinary tract stones
# 22915      38464           Phenazopyridine                      dysuria
# 28993      62810                    Cozaar          high blood pressure
# 21827     169402            Diethylpropion                      obesity
# 61734     228346                   Butrans                         pain
# 67354      29772                Topiramate                      obesity
# 131984     83363                     Paxil                   depression
# 57440     167547            Levonorgestrel      emergency contraception
# 96573     134298                  Lidoderm                         pain
# 104261     41926                Etanercept          psoriatic arthritis
# ...

# %% [markdown]
# After doing the preprocessing, in some reviews we find \r, \n and emojis and @amp for and . So remove them also

# %%
emoji_pattern = re.compile(
    "["
    u"\U0001F600-\U0001F64F"
    u"\U0001F300-\U0001F5FF"
    u"\U0001F680-\U0001F6FF"
    u"\U0001F1E0-\U0001F1FF"
    "]+",
    flags=re.UNICODE,
)

# %%
df['review'] = (df['review'].str.replace(r'[\n\r]+', ' ', regex=True).str.replace(emoji_pattern, '', regex=True))

# %%
df['review'] = df['review'].str.replace('&amp;', 'and', regex=True)
df['review'] = df['review'].str.replace('&quot;', 'and', regex=True)

# %%
df.sample(20)
# Out:
#         uniqueID                                 drugName  \
# 34279      60895                              Oramorph SR
# 30544     145851                                   Qsymia
# 58348     203568  Hydrocortisone / neomycin / polymyxin b
# 78119      97300                                   Ambien
# 19748     214725                                 Warfarin
# 14769     206390                               Mesalamine
# 42031      78712                       OnabotulinumtoxinA
# 116231    119224                             Testosterone
# 5061       40988                Acetaminophen / oxycodone
# 44509     190891                          Tessalon Perles
# 21857     122040                              Venlafaxine
# 80122      89168                                   Celexa
# 21011     175853                                 Levaquin
# 83863      35034                              Minocycline
# 4848       14947        Ethinyl estradiol / norethindrone
# ...

# %% [markdown]
# Now the review and conditions looks good

# %% [markdown]
# ## Feature Engineering

# %%
df.drop(columns=['date','year','month','day','uniqueID'],inplace=True)

# %%
df.sample()
# Out:
#                                 drugName      condition  \
# 134323  Ethinyl estradiol / norgestimate  birth control
#
#                                                    review  rating  usefulCount
# 134323  "switched from yasmin to tri-sprintec (third t...       2            5

# %%
df['sentiment'] = df["rating"].apply(lambda x: 1 if x > 5 else 0)

# %%
df.sample(5)
# Out:
#             drugName                            condition  \
# 121087       Tamiflu                            influenza
# 6688        TriNessa  3 users found this comment helpful.
# 148463      Diclegis         nausea/vomiting of pregnancy
# 91672   Depo-Provera            abnormal uterine bleeding
# 34998    Propranolol                        mance anxiety
#
#                                                    review  rating  \
# 121087  "i had a fever of 102 for 2 days with flu symp...       1
# 6688    "when i read reviews of trinessa after i got p...      10
# 148463  "i want to throw a ticker tape parade for the ...      10
# 91672   "worsed birth control ever i got it jan12 its ...       1
# 34998   "this medication has helped me tremendously wi...      10
#
#         usefulCount  sentiment
# 121087           11          0
# 6688              3          1
# 148463           21          1
# 91672            17          0
# 34998            32          1

# %% [markdown]
# #### Feature representation

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\91939\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords

sw_list = stopwords.words('english')
df['review'] = df['review'].apply(lambda x: [item for item in x.split() if item not in sw_list]).apply(lambda x:" ".join(x))

# %%
df.sample(5)
# Out:
#                                 drugName                    condition  \
# 101894                            Lysine  herpes simplex, suppression
# 71344                             Elavil          migraine prevention
# 138147     Guaifenesin / pseudoephedrine   cough and nasal congestion
# 125089  Ethinyl estradiol / etonogestrel                birth control
# 20403                        Milnacipran                  ibromyalgia
#
#                                                    review  rating  \
# 101894  "i accidentally found lysine surfing internet....      10
# 71344   "my migraines went several week month. sedatin...       9
# 138147  "took 7pm wide awake 1:40 right now! sleep sig...       7
# 125089  "so switched pill great aside remember take it...       5
# 20403   "savella changed life! im 23 years old diagnos...      10
#
#         usefulCount  sentiment
# 101894           38          1
# 71344            10          1
# 138147           14          1
# ...

# %%
df.loc[df['condition'] == '0 users found this comment helpful.'].shape
# Out:
# (128, 6)

# %%
df['condition'] = df['condition'].str.replace('0 users found this comment helpful.', 'Not Specified', regex=True)

# %%
df.loc[df['condition'] == 'Not Specified'].head(3)
# Out:
#                 drugName      condition  \
# 516       Nortrel 1 / 35  Not Specified
# 553       Loestrin 24 Fe  Not Specified
# 571  Ortho Tri-Cyclen Lo  Not Specified
#
#                                                 review  rating  usefulCount  \
# 516  "they switched necon nortrel saying andsameand...       2            0
# 553  "i loestrin 24 fe 6 months never problems emot...       7            0
# 571  "i love birth control spotting periods. little...       9            0
#
#      sentiment
# 516          0
# 553          1
# 571          1

# %%
from nltk.stem import SnowballStemmer
from textblob import TextBlob

# %%
Snow_ball = SnowballStemmer("english")
df['review'] = df['review'].apply(lambda x: " ".join(Snow_ball.stem(word) for word in x.split()))

# %%
df.sample(3)
# Out:
#                                  drugName      condition  \
# 75171                 Medroxyprogesterone  birth control
# 90356   Ethinyl estradiol / norethindrone  birth control
# 136458                         Ivermectin        rosacea
#
#                                                    review  rating  \
# 75171   "i depo 11 year now. month spot got 1st inject...       9
# 90356   "worst experi ever!!!! bc gave sever depress m...       1
# 136458  "so far, good! ive rosacea 20 years. ive good ...      10
#
#         usefulCount  sentiment
# 75171             1          1
# 90356             5          0
# 136458           23          1

# %%
# to determine the polarity of the review
def sentiment(review):
    pol = []
    for i in review:
        analysis = TextBlob(i)
        pol.append(analysis.sentiment.polarity)
    return pol

# %%
df['review_sentiment'] = sentiment(df['review'])

# %%
df.sample(10)
# Out:
#               drugName                 condition  \
# 29208        Meclizine                    vertig
# 30521   Levonorgestrel             birth control
# 11551            Senna              constipation
# 135106      Sertraline                depression
# 128301      Gabapentin          neuropathic pain
# 111669     Phentermine               weight loss
# 157367         Viibryd                depression
# 46048             Duac                      acne
# 148110     Linaclotide  irritable bowel syndrome
# 50062      Dulaglutide          diabetes, type 2
#
#                                                    review  rating  \
# 29208   "i take need year now. experienc bad vertigo e...       8
# 30521   "i skyla iud put decemb 13th (i believ that da...      10
# 11551   "mi doctor prescrib senokot 8.6mg tablets, 1x ...       5
# 135106  "i 22 year old male doctor prescrib sertralin ...       6
# 128301  "ive take gabapentin neuropathi left knee due ...      10
# ...

# %%
df.corr(numeric_only=True)
# Out:
#                     rating  usefulCount  sentiment  review_sentiment
# rating            1.000000     0.235121   0.916406          0.287993
# usefulCount       0.235121     1.000000   0.212763          0.073422
# sentiment         0.916406     0.212763   1.000000          0.261538
# review_sentiment  0.287993     0.073422   0.261538          1.000000

# %%
import nltk
nltk.download('punkt_tab')
from nltk import sent_tokenize
import gensim
from gensim.utils import simple_preprocess
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\91939\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
df['rev_tokens'] = df['review'].apply(simple_preprocess)
df['con_tokens'] = df['condition'].apply(simple_preprocess)

# %%
from gensim.models import Word2Vec

rev_sentences = df['rev_tokens'].tolist()
con_sentenses = df['con_tokens'].tolist()
corpus = rev_sentences + con_sentenses

w2v_model = Word2Vec(
    sentences=corpus,
    vector_size=100,
    window=5,
    min_count=2,
    workers=4
)

# %%
w2v_model.train(corpus,total_examples=w2v_model.corpus_count,epochs=w2v_model.epochs)
# Out:
# (42792653, 48073060)

# %%
def vectorize(text):
    tokens = text.split()
    vectors = [w2v_model.wv[word] for word in tokens if word in w2v_model.wv]
    if not vectors:
        return np.zeros(w2v_model.vector_size)
    return np.mean(vectors, axis=0)

# %%
df['condition_vector'] = df['condition'].apply(vectorize)

# %%
df['condition_vector'].iloc[0]
# Out:
# array([ 0.44040358,  0.308583  , -1.3306929 ,  1.2620236 ,  1.1742992 ,
#        -1.1445535 , -0.40372422,  0.23782633,  0.17013057, -0.9626139 ,
#         0.61594665, -0.9267085 ,  0.17866729,  0.3592577 ,  0.79369617,
#         0.0603021 ,  1.245443  ,  0.21637051,  0.6089124 , -0.7074695 ,
#        -0.16275088, -0.82661295, -0.7522227 ,  0.3894603 ,  0.02852034,
#        -0.49208963, -0.3565465 , -0.6827517 , -0.09212559, -0.7029851 ,
#         1.6402577 , -0.6217474 ,  0.03879523,  0.3430744 ,  1.1103483 ,
#         0.7154978 , -1.0589803 ,  0.4722174 , -0.89478666, -0.5758057 ,
#        -0.63215345, -0.19434972, -0.42339435, -0.5432268 , -0.69602376,
#         0.79880875,  0.6869033 ,  0.728831  , -0.6468014 ,  1.4142507 ,
#         0.67201835, -0.18722801, -0.45408168,  0.36529222, -0.3442619 ,
#         1.367651  , -0.85401756, -0.70812243, -1.0887398 , -0.49719915,
#         0.11590267,  0.04368532,  1.3334128 , -0.15411012, -0.35347402,
# ...

# %%
df['review_vector'] = df['review'].apply(vectorize)

# %%
df['review_vector'].iloc[0]
# Out:
# array([ 0.52576256,  0.12297017,  0.6796313 ,  0.5156695 , -0.3097193 ,
#         0.30922952,  0.73828596, -0.16093528, -0.92072266, -1.2122447 ,
#         0.64327866, -0.561583  ,  0.96100235, -0.3048414 ,  0.22588898,
#         1.0778452 , -0.7867009 ,  0.43013635, -2.2368832 ,  0.23035222,
#         0.04543009,  0.3448781 ,  1.0494955 , -0.474654  ,  1.405217  ,
#         1.6587685 ,  0.45099807, -0.89163023,  0.91046524, -0.47304973,
#        -0.0768854 ,  0.2206447 , -0.7401962 , -0.5783179 ,  0.20486403,
#        -0.34703043, -0.39907718,  0.21123837,  0.8329732 , -0.90631557,
#         0.00430225, -0.9627893 , -0.87199   ,  0.72018737,  0.043615  ,
#         0.54284286, -0.2902408 ,  0.44356766, -0.15630682,  0.9057183 ,
#        -0.3566265 , -0.26767972,  0.24576147,  0.36282277,  0.6870379 ,
#         0.73099875,  0.6930762 , -0.99508524, -0.52050346,  0.46273682,
#        -0.2329249 ,  0.31162313,  0.3167942 ,  0.66253066,  0.04081163,
# ...

# %%
df.sample()
# Out:
#                                 drugName      condition  \
# 92164  Ethinyl estradiol / norethindrone  birth control
#
#                                                   review  rating  usefulCount  \
# 92164  "ive loestrin 24 month one week, went 112 117 ...       1            5
#
#        sentiment  review_sentiment  \
# 92164          0             -0.15
#
#                                               rev_tokens        con_tokens  \
# 92164  [ive, loestrin, month, one, week, went, breat,...  [birth, control]
#
#                                         condition_vector  \
# 92164  [0.9027256, 1.7496446, 1.9331102, -1.0457298, ...
#
#                                            review_vector
# 92164  [0.29757446, -0.13231014, 0.6820493, -0.409959...

# %%
df.drop(columns=['rev_tokens','con_tokens'],inplace=True)

# %%
df.shape
# Out:
# (213869, 9)

# %%
grouped = df.groupby(['condition','drugName']).agg({
    'review_vector': lambda x: np.mean(np.vstack(x), axis=0),
    'condition_vector': 'first',
    'review_sentiment': ['mean', 'std'],
    'rating': ['mean', 'count'],
    'usefulCount': 'sum'
}).reset_index()

# %%
grouped.columns = [
    'condition',
    'drugName',
    'review_vector',
    'condition_vector',
    'mean_sentiment',
    'std_sentiment',
    'mean_rating',
    'review_count',
    'useful_sum'
]

# %%
X_review = np.vstack(grouped['review_vector'].values)
X_condition = np.vstack(grouped['condition_vector'].values)

X_numeric = grouped[['mean_sentiment',
                     'std_sentiment',
                     'mean_rating',
                     'review_count',
                     'useful_sum']].values

# %%
cond_dim = X_condition.shape[1]
rev_dim = X_review.shape[1]

cond_cols = [f'cond_emb_{i}' for i in range(cond_dim)]
rev_cols  = [f'rev_emb_{i}' for i in range(rev_dim)]

num_cols = [
    'mean_sentiment',
    'std_sentiment',
    'mean_rating',
    'review_count',
    'useful_sum'
]
columns = cond_cols + rev_cols + num_cols

# %%
X = np.hstack([X_condition, X_review, X_numeric])

# %%
X_df = pd.DataFrame(X, columns=columns)

# %%
X_df.isnull().sum()
# Out:
# cond_emb_0           0
# cond_emb_1           0
# cond_emb_2           0
# cond_emb_3           0
# cond_emb_4           0
#                   ...
# mean_sentiment       0
# std_sentiment     3415
# mean_rating          0
# review_count         0
# useful_sum           0
# Length: 205, dtype: int64

# %%
df = df.reset_index(drop=True)

# %%
X_df['drugName']=df['drugName']

# %%
Y_df = X_df['mean_sentiment']

# %%
X_df.drop(columns=['mean_sentiment'],inplace = True)

# %%
Y_df.shape
# Out:
# (9446,)

# %%
sns.kdeplot(Y_df)
# Out:
# <Axes: xlabel='mean_sentiment', ylabel='Density'>

# %%
Y_df = (grouped['mean_sentiment'] > 0).astype(int)

# %%
X_df.shape
# Out:
# (9446, 205)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
X_df['drugName'] = le.fit_transform(X_df['drugName'])

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, r2_score, classification_report, f1_score

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X_df,Y_df,test_size=0.2,random_state=42)

# %%
rf = RandomForestClassifier(
    n_estimators=600,
    max_depth=None,
    min_samples_split=5,
    min_samples_leaf=2,
    class_weight='balanced',
    n_jobs=-1,
    random_state=42
)

# %%
rf.fit(X_train,Y_train)

# %%
pred = rf.predict(X_test)

# %%
accuracy_score(Y_test,pred)
# Out:
# 0.864123065413569

# %%
print(confusion_matrix(Y_test, pred))
print(classification_report(Y_test, pred))
# Out:
# [[ 7561  5212]
#  [  600 29401]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.59      0.72     12773
#            1       0.85      0.98      0.91     30001
#
#     accuracy                           0.86     42774
#    macro avg       0.89      0.79      0.82     42774
# weighted avg       0.87      0.86      0.85     42774

# %%
from sklearn.metrics import roc_auc_score
rf_prob = rf.predict_proba(X_test)[:,1]
roc_auc_score(Y_test, rf_prob)

# %%
neg = (Y_train == 0).sum()
pos = (Y_train == 1).sum()
scale = neg / pos

# %%
from xgboost import XGBClassifier

model = XGBClassifier(
    objective='binary:logistic',
    eval_metric='logloss',
    tree_method='hist',
    max_depth=6,
    learning_rate=0.05,
    n_estimators=500,
    subsample=0.8,
    colsample_bytree=0.8,
    scale_pos_weight=neg/pos
)

model.fit(X_train, Y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=500, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
xg_pred = model.predict(X_test)

# %%
accuracy_score(Y_test,xg_pred)
# Out:
# 0.8164021164021164

# %%
Y_train.value_counts(normalize=True)
# Out:
# mean_sentiment
# 1    0.724325
# 0    0.275675
# Name: proportion, dtype: float64

# %%
from sklearn.metrics import classification_report, confusion_matrix

print(confusion_matrix(Y_test, xg_pred))
print(classification_report(Y_test, xg_pred))
# Out:
# [[ 300  224]
#  [ 123 1243]]
#               precision    recall  f1-score   support
#
#            0       0.71      0.57      0.63       524
#            1       0.85      0.91      0.88      1366
#
#     accuracy                           0.82      1890
#    macro avg       0.78      0.74      0.76      1890
# weighted avg       0.81      0.82      0.81      1890

# %%
X_review = np.vstack(df['review_vector'].values)
X_condition = np.vstack(df['condition_vector'].values)

# %%
X_numeric = df[['usefulCount']].values

# %%
X = np.hstack([X_condition, X_review, X_numeric])

# %%
cond_dim = X_condition.shape[1]
rev_dim = X_review.shape[1]

cond_cols = [f'cond_emb_{i}' for i in range(cond_dim)]
rev_cols  = [f'rev_emb_{i}' for i in range(rev_dim)]

columns = cond_cols + rev_cols + ['usefulCount']

# %%
X_df = pd.DataFrame(X,columns=columns)

# %%
X_df
# Out:
#         cond_emb_0  cond_emb_1  cond_emb_2  cond_emb_3  cond_emb_4  \
# 0         0.440404    0.308583   -1.330693    1.262024    1.174299
# 1        -0.573058   -2.519679    0.722316   -4.149639   -0.355820
# 2         0.902726    1.749645    1.933110   -1.045730   -1.921899
# 3         0.902726    1.749645    1.933110   -1.045730   -1.921899
# 4         0.303041    0.981727   -1.368785    0.468331    1.365427
# ...            ...         ...         ...         ...         ...
# 213864   -1.652719    0.598822    0.261088   -0.328607   -1.458277
# 213865   -1.795872   -3.081064   -0.356108   -0.998420    1.773565
# 213866    0.902726    1.749645    1.933110   -1.045730   -1.921899
# 213867   -1.589723    1.139642   -1.587686    0.707659    1.214436
# 213868   -1.292673    0.304564   -1.148449    0.419066   -0.713045
#
#         cond_emb_5  cond_emb_6  cond_emb_7  cond_emb_8  cond_emb_9  ...  \
# 0        -1.144554   -0.403724    0.237826    0.170131   -0.962614  ...
# ...

# %%
X_df['review_sentiment']=df['review_sentiment']

# %%
X_df['useful_log'] = np.log1p(X_df['usefulCount'])

# %%
Y_df = df['sentiment']

# %%
X_df.sample()
# Out:
#         cond_emb_0  cond_emb_1  cond_emb_2  cond_emb_3  cond_emb_4  \
# 182259   -1.589723    1.139642   -1.587686    0.707659    1.214436
#
#         cond_emb_5  cond_emb_6  cond_emb_7  cond_emb_8  cond_emb_9  ...  \
# 182259    2.349205   -3.317805    0.045703   -0.566447    1.938814  ...
#
#         rev_emb_93  rev_emb_94  rev_emb_95  rev_emb_96  rev_emb_97  \
# 182259   -0.148379   -0.237017   -0.136498   -0.319239   -0.404382
#
#         rev_emb_98  rev_emb_99  usefulCount  review_sentiment  useful_log
# 182259    0.994876   -0.123021          6.0          0.195833     1.94591
#
# [1 rows x 203 columns]

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X_df,Y_df,test_size=0.2,random_state=42)

# %%
from xgboost import XGBClassifier
neg = (Y_train == 0).sum()
pos = (Y_train == 1).sum()

model = XGBClassifier(
    objective='binary:logistic',
    eval_metric='logloss',
    tree_method='hist',
    max_depth=6,
    learning_rate=0.05,
    n_estimators=600,
    subsample=0.8,
    colsample_bytree=0.8,
    min_child_weight=3,
    gamma=0.1,
    reg_lambda=1.5,
    scale_pos_weight=neg/pos
)

model.fit(X_train, Y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=0.1,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=3, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=600, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
xg_pred = model.predict(X_test)

# %%
print(confusion_matrix(Y_test, xg_pred))
print(classification_report(Y_test, xg_pred))
# Out:
# [[10423  2350]
#  [ 5081 24920]]
#               precision    recall  f1-score   support
#
#            0       0.67      0.82      0.74     12773
#            1       0.91      0.83      0.87     30001
#
#     accuracy                           0.83     42774
#    macro avg       0.79      0.82      0.80     42774
# weighted avg       0.84      0.83      0.83     42774

# %%
accuracy_score(Y_test,xg_pred)
# Out:
# 0.8262729695609482

# %%
y_prob = model.predict_proba(X_test)[:, 1]

for t in [0.52, 0.55, 0.58, 0.6]:
    preds = (y_prob > t).astype(int)
    print(t, f1_score(Y_test, preds, average='macro'))
# Out:
# 0.52 0.7997151150049007
# 0.55 0.7926275711120312
# 0.58 0.7836189349908518
# 0.6 0.7767634265205179

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(Y_test, y_prob)
# Out:
# np.float64(0.9056071483595449)

# %%
from lightgbm import LGBMClassifier

model = LGBMClassifier(
    n_estimators=700,
    learning_rate=0.05,
    num_leaves=31,
    subsample=0.8,
    colsample_bytree=0.8
)

# %%
model.fit(X_train, Y_train)
# Out:
# [LightGBM] [Info] Number of positive: 119962, number of negative: 51133
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.318623 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 47885
# [LightGBM] [Info] Number of data points in the train set: 171095, number of used features: 203
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.701143 -> initscore=0.852745
# [LightGBM] [Info] Start training from score 0.852745
# LGBMClassifier(colsample_bytree=0.8, learning_rate=0.05, n_estimators=700,
#                subsample=0.8)

# %%
lg_pred = model.predict(X_test)

# %%
accuracy_score(Y_test,lg_pred)
# Out:
# 0.8325384579417403

# %%
importance = pd.Series(model.feature_importances_)
importance.sort_values(ascending=False).head(20)
# Out:
# 200    404
# 201    290
# 172    286
# 120    272
# 103    269
# 102    264
# 122    256
# 184    249
# 175    246
# 180    236
# 101    234
# 157    234
# 129    232
# 135    231
# 133    229
# 128    225
# 125    222
# 173    220
# 106    210
# 140    210
# dtype: int32
