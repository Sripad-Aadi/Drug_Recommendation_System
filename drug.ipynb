# %% [markdown]
# ## Data Aggrigation

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_train = pd.read_csv('drugsComTrain_raw.csv')
df_test = pd.read_csv('drugsComTest_raw.csv')

# %%
data = pd.concat([df_train,df_test])

# %%
data.shape
# Out:
# (215063, 7)

# %%
df = data.copy()

# %%
df.sample(5)
# Out:
#         uniqueID      drugName             condition  \
# 50885      22012    Infliximab  Rheumatoid Arthritis
# 64681     198760  Depo-Provera         Birth Control
# 65230      57059       MiraLax          Constipation
# 66286     145105  Etonogestrel         Birth Control
# 157749     94634       Abilify            Depression
#
#                                                    review  rating       date  \
# 50885   "For two year (09&#039; 10&#039;) we were tryi...       9  26-Feb-12
# 64681   "If I could rate this product less than 1 I wo...       1  23-Nov-16
# 65230   "I&#039;ve had chronic constipation since I wa...      10  20-Sep-16
# 66286   "I gained 15 pounds, didn&#039;t have periods ...      10   7-Nov-15
# 157749  "Been on the drug for a few months now put on ...       1  12-May-16
#
#         usefulCount
# 50885            47
# 64681             4
# 65230            51
# 66286             2
# 157749           13
